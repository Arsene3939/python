# %%
import numpy as np
import matplotlib.pyplot as plt
X=np.linspace(-5,5,1000)
def dy_dx(func):
    dx=[]
    for i in X:
        dx.append(func(i+1)-func(i))
    return dx
def f(x):
    return (-(x**2)+30)**0.5
fig,ax=plt.subplots(figsize=(5,5))
ax.plot(X,f(X),X,dy_dx(f))
# Out:
# C:\Users\willy7086\anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.
# ...
