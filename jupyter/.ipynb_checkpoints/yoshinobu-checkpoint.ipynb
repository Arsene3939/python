# %%
import matplotlib.pyplot as plt
import numpy as np
yoshino=plt.imread('image\\shinobu.png')
def drawline(im,x1,y1,x2,y2,color=0,width=20):
    x=x1
    y=y1
    y2-=width
    x2-=width
    dx=x2-x1
    dy=y2-y1
    linpoint=np.sqrt(dx**2+dy**2)
    while x<x2 and y<y2:
        x+=dx/1000
        y+=dy/1000
        for i in range(3):
            for j in range(width):
                im[int(y)+j][int(x)+j][i]=0xFF*(color==i)/255
def test(im,x1,y1,x2,y2,color=0):
    pa=[]
    x=x1
    y=y1
    dx=x2-x1
    dy=y2-y1
    linpoint=np.sqrt(dx**2+dy**2)
    while x<x2 and y<y2:
        x+=dx/1000
        y+=dy/1000
        np.array(pa.append([int(x),int(y)]))
    for g in range(len(pa)):
        for j in range(pa[g][0]):#x
            for c in range(3):
                im[pa[g][1]][j][c]=0xFF*(color==c)/255
def drawrect(im,A,B,C,D,color=0):
    Ax=A[0]
    Ay=A[0]
    Bx=B[0]
    By=B[0]
    Cx=C[0]
    Cy=C[0]
    Dx=D[0]
    Dy=D[0]
test(yoshino,0,0,520,740)
plt.imshow(yoshino)

# %%
x=1
y=2
a=[x,y]
a
# Out:
# [1, 2]

# %%
import matplotlib.pyplot as plt
import numpy as np
yoshinobu=plt.imread('image\\yoshinobu.png')
yoshino=plt.imread('image\\yoshino.png')
shino=plt.imread('image\\shino.png')
shinobu=plt.imread('image\\shinobu.png')
yoshino=yoshino[:740,:530,:]
shino=shino[:740,:530,:]
shinobu=shinobu[:740,:530,:]
fig,ax=plt.subplots(figsize=(12,6),nrows=1,ncols=1)
fig2,ax2=plt.subplots(figsize=(12,6))
ax.imshow(np.hstack((np.hstack((yoshino,shino)),shinobu)))
