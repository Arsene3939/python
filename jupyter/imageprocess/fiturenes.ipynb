# %%
import numpy as np
import matplotlib.pyplot as plt
fig,ax=plt.subplots(figsize=(16,19),nrows=2)
img=plt.imread('D:\\Desktop\\test.png')
ax[0].imshow(img)
img=np.array(img)
img[:,:,:3]*=0.8
ax[1].imshow(img)
plt.imsave('D:\\Desktop\\test1.png',img)
