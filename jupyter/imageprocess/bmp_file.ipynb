# %%
import numpy as np
import matplotlib.pyplot as plt
a=plt.imread("image\\72406145_0.jpg")
n_bit_image=np.full([160,128],1)
data=0
for y in range(len(a)):
    for x in range(len(a[0])):
        data=0
        for color in range(3):
            data=data+((a[y][x][color]//32)<<(color*3))
        n_bit_image[y][x]=data
        print("%10s,"%bin(data),end='')
    print()
plt.imshow(x)
# Out:
# 0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10001111,0b10001111,0b11010111,0b11010111,0b10001111,0b11001111,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b11010111,0b10001111,0b11010111,0b11010111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10001111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b11010111,0b11010111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11001111,0b11001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b100101
# ...

# %%
a="""0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10001111,0b10001111,0b11010111,0b11010111,0b10001111,0b11001111,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b11010111,0b10001111,0b11010111,0b11010111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10001111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b11010111,0b11010111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11001111,0b11001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b11010111,0b11010111,0b10010101,0b101101110,0b111111111,0b111111111,0b111111111,0b111110111,0b110101111,0b111111111,0b111110111,0b101101111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010111,0b10001111,0b10001111,0b10001111,0b100011111,0b101100111,0b100011111,0b10001111,0b10001111,0b11010111,0b10001111,0b10001111,
0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10001111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10001111,0b11010111,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b100011111,0b111110111,0b111111111,0b110110111,0b110101111,0b100011111,0b101100111,0b100100111,0b10010110,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010110,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,
0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b11010111,0b11010111,0b11001111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11011111,0b11010111,0b11010111,0b11010111,0b10001111,0b10001111,0b10010111,0b11010111,0b10010111,0b10001111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b11010111,0b11010111,0b11010111,0b11010111,0b11001111,0b11010111,0b11010111,0b11010111,0b11001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010110,0b11010111,0b11010111,0b10001111,0b10001111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b11001111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10001111,0b11010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010110,0b11011111,0b11010111,0b11001111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010110,0b100100111,0b111110111,0b100100111,0b10010111,0b11001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11001111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,
0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10001111,0b10010111,0b10001110,0b101101111,0b111110111,0b11010111,0b11010111,0b11001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11001111,0b11001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b101100111,0b111110111,0b110101111,0b11010110,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b11001111,0b10001111,0b11010111,0b110101111,0b100011111,0b10001111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11001111,0b11010111,0b11010111,0b11001111,0b10001111,0b10010111,0b10010111,0b10001111,0b11001111,0b11001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b100011111,0b11010111,0b10001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11001111,0b11010111,0b11010111,0b10010110,0b100100111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b100011111,0b101100111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11001111,0b11001111,0b11010111,0b11010111,0b10010110,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11001111,0b10001111,0b11010111,0b11010111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11011111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b10010111,0b11010111,0b11010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b10001111,0b11010111,0b10001111,0b10001111,0b11010111,0b11010111,0b11001111,0b10001111,0b10010110,0b110110111,0b111111111,0b11011110,0b11001111,0b11010110,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010110,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11001111,0b11010111,0b10010111,0b11010110,0b101101110,0b110111111,0b101101111,0b11010110,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b11010111,0b11010111,0b11010111,0b10001111,0b11010111,0b10001111,0b10010111,0b11011111,0b101101111,0b10010111,0b10010111,0b10001111,0b10010111,0b11010111,0b10001111,0b11001111,0b10001111,0b10010111,0b11010111,0b10010111,0b11010111,0b11010111,0b10001111,0b11010111,0b10010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11001111,0b10001111,0b101100111,0b111111111,0b111111111,0b111111111,0b101101111,0b100010111,0b101101111,0b100011111,0b10001111,0b11001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10001111,0b10010110,0b10010110,0b11011110,0b100100111,0b100100111,0b100100111,0b100100111,0b100100111,0b100011110,0b11010110,0b11010110,0b10010110,0b11010110,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b100011111,0b111111111,0b110111111,0b110111111,0b110110111,0b101100111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11001111,0b11010111,0b11010111,0b10010111,0b10010110,0b11010111,0b10010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10001111,0b11010111,0b10010111,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b100011111,0b11011110,0b101110111,0b111111111,0b111111111,0b111111111,0b101100111,0b101100111,0b11010111,0b10010111,0b11010111,0b11010111,0b10001111,0b11010111,0b10010111,0b10010111,0b10001111,0b10001111,0b11010111,0b11010110,0b10010101,0b11011110,0b101100111,0b110101111,0b111111111,0b111111111,0b110110111,0b110101110,0b110101110,0b101101110,0b110101110,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b110101111,0b101100110,0b100011110,0b11010101,0b11010111,0b11010111,0b11001111,0b10001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b10010111,0b101101111,0b111111111,0b110110111,0b110110111,0b110101111,0b11010111,0b11010111,0b11001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b10010111,0b11010111,0b11010111,0b10001111,0b10010111,0b11010111,0b11010111,0b100011111,0b10010110,0b100100111,0b110110111,0b100100111,0b10001111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b100100111,0b110101111,0b11010101,0b111111111,0b111111111,0b101101111,0b11010110,0b11010111,0b11010110,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10010111,0b11010111,0b11010111,0b10001110,0b11011111,0b101101111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110110,0b111111111,0b111111111,0b111111110,0b111111110,0b111110101,0b111110110,0b111110110,0b111111111,0b111111111,0b111111111,0b111110111,0b100011111,0b10010110,0b10001110,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10001111,0b10010111,0b100100111,0b11011101,0b11010111,0b11010111,0b11010111,0b11010111,0b11001111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010110,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10001111,0b11001111,0b11010111,0b11010111,0b101100111,0b10010111,0b101100111,0b110111111,0b100100111,0b10010110,0b10010111,0b10010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10001111,0b11010111,0b10010111,0b11010111,0b10001111,0b11010111,0b101100111,0b11010110,0b11010111,0b11001111,0b11001111,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b11010111,0b10010110,0b100011110,0b110110111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b101100111,0b10010110,0b10010110,0b11010111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11001111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b101101111,0b101101111,0b101100111,0b101100111,0b10001111,0b11001111,0b10010111,0b10010111,0b11010111,0b10001111,0b11010111,0b100011111,0b10010111,0b11010111,0b10001111,0b10001111,0b11010111,0b11010111,0b11010111,0b10001111,0b10010111,0b11010111,0b10010110,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010111,0b11001111,0b10001111,0b11001111,0b11001111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b11010111,0b11010110,0b101100111,0b101100101,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111110,0b110110101,0b101110101,0b111111111,0b111111111,0b110101111,0b100011111,0b10001110,0b10001111,0b11010111,0b10010111,0b11010111,0b10010111,0b11010111,0b10001111,0b10001111,0b10010111,0b11010111,0b10010111,0b11010111,0b11010111,0b10010111,0b11010111,0b10010111,0b11010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b100011111,0b111110111,0b111111111,0b111111111,0b100100111,0b11010111,0b11001111,0b10001111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11001111,0b11001111,0b11001111,0b10001111,0b10010111,0b11010111,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010110,0b11010101,0b100100110,0b110110110,0b111111111,0b111111110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111110,0b101101101,0b101101101,0b101101110,0b111111111,0b111111111,0b101100111,0b10010101,0b11010110,0b11010111,0b10010111,0b11010111,0b10001111,0b10001111,0b11010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010111,0b10010110,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010110,0b100100111,0b101101111,0b100011110,0b10010110,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010110,0b100100110,0b110110111,0b11011111,0b10001111,0b11001111,0b10001111,0b100011111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001110,0b10001101, 0b1001100,0b10001100,0b11010100,0b110110111,0b110110110,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111110,0b100011011,0b101100101,0b111111111,0b111111111,0b101100111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b11010111,0b11011111,0b10010111,0b11011111,0b110101111,0b10010110,0b11010111,0b11010111,0b11010111,0b10001111,0b11010111,0b101101111,0b100011111,0b10010110,0b100011111,0b11011111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b111111111,0b111111111,0b111111111,0b11011110,0b11001111,0b11010111,0b11010111,0b10010110,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,
0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11001111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11001111,0b11010110,0b10001101,0b10001100,0b10001100,0b10001101,0b10001100,0b11011101,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110110,0b110110110,0b111111111,0b111111111,0b110110110,0b111110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110110,0b111111111,0b101101110,0b10001100,0b100011111,0b110110111,0b111111111,0b101101110,0b11010101,0b11010111,0b10001111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b100011111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010110,0b101101111,0b111111111,0b111111111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b100100111,0b110110111,0b101101111,0b100100111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010110,0b11010110,0b10001100, 0b1000011,0b10001101,0b10001110, 0b1001100,0b11011100,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111110,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b110101101,0b111111111,0b111111111,0b110110110,0b111111111,0b111110110,0b101101101,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b11010101,0b10010101,0b100011111,0b110110111,0b111110111,0b11011110,0b11010110,0b10010111,0b10010111,0b10001111,0b11001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11011111,0b100100111,0b110110111,0b11011110,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b11010111,0b10010111,0b10001111,0b11010111,0b10010111,0b11010111,0b10010111,0b11010111,0b11010110,0b100011111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10001111,0b10010111,0b10001111,0b11011111,0b10010110,0b10010101,0b100100111,0b10001101,0b10001100,0b11001100, 0b1001100, 0b1000100,0b10001101,0b101100110,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111110110,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b101101101,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b101101101,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100011110,0b10010110,0b10001111,0b11011111,0b111111111,0b101101110,0b10001110,0b11010111,0b11001111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b11010111,0b10010111,0b10010111,0b11001111,0b10001111,0b10001111,0b10010111,0b11001111,0b11010111,0b11010111,0b10010111,0b10001111,0b11010111,0b11010111,0b10010111,0b10001111,0b11001111,0b10001111,0b10001111,0b11010111,0b10010111,0b10001111,0b11001111,
0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b101101111,0b10011110,0b10011101,0b110110111,0b10010100, 0b1001011,0b10001011,0b10001100, 0b1000100,0b11010100,0b111110111,0b110101110,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b101101101,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b110110110,0b111110111,0b111111111,0b111111111,0b101101101,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100011111,0b10001111,0b10010111,0b11010110,0b101101111,0b110101111,0b11010110,0b11010111,0b11010111,0b10001111,0b10010111,0b10001111,0b11010111,0b11010111,0b11001111,0b11010111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010110,0b11010110,0b10010110,0b10010111,0b11001111,0b10001111,0b11010111,
0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010110,0b11100111,0b101101111,0b100101111,0b10010101,0b11100110,0b11100110,0b10010100, 0b1001011,0b11010101, 0b1000011,0b100011101,0b111110111,0b110101101,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b110110110,0b110110110,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b101101101,0b111111111,0b111111111,0b111111111,0b110101101,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100011111,0b11010110,0b11010111,0b10001110,0b11010111,0b110101111,0b11010110,0b10010110,0b10010111,0b10001111,0b10010111,0b10001111,0b11001111,0b11010111,0b11001111,0b10001111,0b10010111,0b10001111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b11010111,0b10010111,0b100100111,0b100011111,0b10010111,0b11010111,0b101101111,0b100011111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b101101111,0b110110111,0b101101111,0b100011111,0b11010111,0b11010111,0b10010111,
0b11010111,0b11010111,0b11001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11011111,0b100101111,0b100101111,0b11100110,0b11011110,0b11100111,0b10011101,0b11011110,0b11011101,0b10010101,0b11011101,0b101101110,0b110101101,0b111110110,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b110110110,0b110101101,0b111111111,0b111111111,0b111111111,0b110110110,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111110,0b111111111,0b111111111,0b100011111,0b10001111,0b10001111,0b11010111,0b10010110,0b101101111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11001111,0b11001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10010111,0b101101111,0b100100111,0b10010111,0b11010111,0b11010110,0b10010110,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b110101111,0b111111111,0b111111111,0b110101111,0b10001111,0b11010111,0b11010111,
0b11010111,0b11010111,0b10001111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b11011111,0b11100111,0b101110111,0b10011110, 0b1010101,0b10010101,0b11011110,0b11010110,0b101101111,0b101101111,0b100101111,0b100101111,0b100100110,0b101100101,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b110110110,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b101100100,0b111110110,0b111111111,0b111111111,0b110110110,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111110,0b111111111,0b11011111,0b10010111,0b10010111,0b11010111,0b10010110,0b100100111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11011111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b100011111,0b110110111,0b111111111,0b110101111,0b11010111,0b10010111,0b11010111,
0b11001111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010110,0b10010110,0b10011101,0b10011101,0b11011110,0b101101111,0b10010100,0b101100111,0b11011111,0b10010101,0b100101111,0b100101111,0b11100111,0b11011110,0b101100101,0b111111111,0b111111111,0b111111111,0b111111111,0b110101101,0b110101101,0b111111111,0b111111110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b110101101,0b111110110,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111110,0b110110110,0b111111111,0b11011101,0b10010111,0b10010111,0b10010111,0b10010111,0b100011111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11001111,0b11010111,0b10010111,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11001111,0b11010111,0b11010110,0b100100111,0b101101111,0b11010110,0b11010111,0b10001111,
0b11001111,0b11001111,0b100011111,0b11010111,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11011111,0b100100111, 0b1001101, 0b1010101, 0b1010101,0b100101111,0b101101111,0b10011110,0b10001100,0b11100110,0b11011110,0b10010101,0b10010110,0b11100111,0b11100111,0b100100110,0b101100101,0b111111111,0b111111111,0b111111111,0b111111111,0b101100100,0b110110110,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111110110,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b101101101,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b110110110,0b111111111,0b10010110,0b10010111,0b10010111,0b11010111,0b11010111,0b100011111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11001111,0b11001111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11001111,0b11001111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,
0b11010110,0b11011111,0b101101111,0b11011111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b11010111,0b10001111,0b10010111,0b11010111,0b10010111,0b10010110,0b101101111,0b10010110, 0b1010101,0b100100111, 0b1010100,0b101101111,0b11011110,0b10011110,0b10010101, 0b1010101,0b11011110, 0b1010101,0b11011111,0b10011110,0b100100111,0b100100101,0b101101101,0b111111111,0b111111111,0b111111111,0b111111111,0b101100100,0b110110110,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b101101101,0b111111111,0b111111111,0b111111111,0b101101101,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111110110,0b101101111,0b10010110,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11001111,0b11001111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010111,0b10010111,0b100011111,0b11010111,0b10010111,0b11010111,0b10010111,
0b100011101,0b111111111,0b111110111,0b11010110,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11001111,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b11011111,0b101101111,0b100100111,0b10010101,0b100101111,0b10011101, 0b1001100,0b10010101,0b10010101, 0b1001100,0b10010101,0b10010110,0b10010101, 0b1001100,0b11011110,0b11011110,0b100100111,0b11011101,0b110101110,0b111111110,0b111111111,0b111111111,0b111111111,0b100011011,0b111110110,0b111111111,0b110110110,0b111110110,0b111111111,0b111110111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b101101101,0b111111111,0b111111111,0b111111111,0b110110110,0b110101110,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110101110,0b111111111,0b101100111,0b10001110,0b10001111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,
0b111111111,0b111111111,0b101100111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11011110,0b101101111,0b10010101,0b11011110,0b11011110,0b10010101, 0b1001100,     0b100, 0b1001101, 0b1010101, 0b1001100,0b11011110,0b10001101,0b11010101, 0b1001100,0b11011110,0b11011110,0b11011101,0b110101110,0b111110110,0b111111111,0b111111111,0b111111111,0b100011011,0b111110110,0b111111111,0b111110110,0b110110110,0b111111111,0b110110110,0b110110110,0b111111111,0b110110110,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b110101101,0b111111111,0b111110111,0b111111111,0b110110111,0b101101101,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110101,0b110110111,0b100011111,0b10010111,0b10001111,0b11010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,
0b111111111,0b111111111,0b11010111,0b10001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010110,0b101101111,0b11011110, 0b1001101,0b10011110, 0b1001100,    0b1100, 0b1001100,0b100100111,0b11011110, 0b1001101,0b11011111,0b10010101,0b100100111, 0b1001100,0b10010101,0b10010100,0b100011101,0b110101110,0b110110110,0b111111111,0b111111111,0b111111111,0b100011011,0b111111111,0b111110111,0b111110111,0b110101110,0b111111111,0b110101101,0b110110110,0b111111111,0b101101101,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b110110110,0b110110110,0b110110111,0b111111111,0b101101101,0b110110110,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110110,0b111111111,0b110101110,0b101101111,0b11010110,0b11010111,0b10001111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,
0b111111111,0b110110111,0b10001110,0b100010111,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010110,0b11011111,0b100101111, 0b1001100, 0b1010101, 0b1001100,      0b11,0b100100111,0b100101111,0b10010110, 0b1001101,0b11011111, 0b1010101,0b11100111,    0b1100, 0b1001100,0b11010100,0b101100100,0b110101101,0b110101110,0b111111111,0b111111111,0b111111111,0b100011011,0b111110111,0b110110110,0b111111111,0b101101101,0b111111111,0b101101101,0b101101101,0b111111111,0b101101101,0b111111111,0b110110110,0b111111111,0b111110110,0b111111111,0b111111111,0b110110110,0b101101101,0b111111111,0b110101110,0b111111111,0b101101101,0b101101110,0b111110111,0b110101110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111110,0b111111110,0b111111111,0b111111111,0b111111111,0b111110110,0b111111111,0b110110110,0b101100111,0b10010110,0b11001111,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b11010111,0b10010111,
0b111111111,0b101100111,0b11010110,0b100011111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001110,0b100100111,0b100100111,0b10010101,0b10010110,0b11011111,0b11011110,0b10010101,0b10010101,0b10010110,0b10010101, 0b1010100,0b11100111,    0b1100,0b11011110,0b100011100,0b101100100,0b110101101,0b110101110,0b111111111,0b111111111,0b111111111,0b100011100,0b111110111,0b110110110,0b111111111,0b101100101,0b111111111,0b101101101,0b101101101,0b111111111,0b101101101,0b111110110,0b111110110,0b110110110,0b110110110,0b111111111,0b111111111,0b111110111,0b101101101,0b111111111,0b101101101,0b111111111,0b101101101,0b101101110,0b111111111,0b101101101,0b111110111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110101,0b111111110,0b111110111,0b11011110,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10001111,0b11010111,0b10010111,0b100011111,
0b111111111,0b11011101,0b101100111,0b10010110,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010110,0b11011110,0b11011110,0b10010110,0b10010110,0b11011110,0b11011110, 0b1001100,0b10010101,0b10010100,0b11011110,0b11011111, 0b1010110,0b100101111,0b100011101,0b101100100,0b101100101,0b110101101,0b111111111,0b111111111,0b111111111,0b100100100,0b110110110,0b110110101,0b111111111,0b101100101,0b111111111,0b101101101,0b100100100,0b111111111,0b101101101,0b110110110,0b111111111,0b110101110,0b110101110,0b111111111,0b111111111,0b111110111,0b101100101,0b111111111,0b101100101,0b111110111,0b101101110,0b100100101,0b110110110,0b101101110,0b110101110,0b111111111,0b111110111,0b110110110,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111110,0b110110101,0b111110111,0b101101111,0b10010110,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b100011111,0b100100111,
0b111111111,0b100011110,0b100011111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10001111,0b11001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11001111,0b11010111,0b10001110,0b11011110,0b11011111, 0b1010101,0b10011101,0b10010100, 0b1001100,0b11011110,0b10010101,0b11011110,0b100011110, 0b1001100,0b11100111,0b100101111,0b100011101,0b101100100,0b101100101,0b101101101,0b111111111,0b111111111,0b111111111,0b100011100,0b110110110,0b101101110,0b111111111,0b100100100,0b110110111,0b101101110,0b100100100,0b110110110,0b110101110,0b101100101,0b111111111,0b101101101,0b110110110,0b110110110,0b111111111,0b110110111,0b101100101,0b111110111,0b101100101,0b110110111,0b101101111,0b100100101,0b110110111,0b110101110,0b101101101,0b110110111,0b111111111,0b101101110,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111110,0b111111111,0b110101110,0b110110110,0b110110110,0b101100110,0b10010110,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10001111,0b11010111,0b10010111,0b100011111,0b110101111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11001111,0b11001111,0b11001111,0b11001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b101100111,
0b110111111,0b110110111,0b10010110,0b11010111,0b10001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10001101,0b10010101,0b10010110, 0b1010101, 0b1010101,0b10010101,0b10011110,0b10010110, 0b1001101,0b11011110,0b10010101, 0b1001101,0b100100111,0b100100111,0b101100110,0b110101101,0b101100100,0b101101101,0b111111111,0b111110111,0b111111111,0b100100101,0b110101110,0b101101101,0b110110111,0b100100101,0b110110111,0b101101110,0b100100100,0b101101110,0b110110111,0b11011100,0b110110111,0b101101101,0b110101101,0b101101110,0b110110111,0b110110111,0b101100101,0b110110110,0b100100100,0b110110111,0b101101110,0b100100101,0b100100101,0b101101101,0b101100101,0b110110110,0b111111111,0b101101110,0b110110110,0b111111111,0b110110110,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b101101100,0b110110110,0b101101110,0b110101111,0b10010110,0b10010111,0b10010111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b10010110,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11011110,0b110101111,
0b111111111,0b101100111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10001111,0b10010111,0b11011111,0b10010110,0b10010101,0b11011111,0b10011110,0b10011111,0b10011111,0b10010110, 0b1001110,0b10010110, 0b1001101,0b11011111,    0b1100,    0b1100,0b10011111,0b11011111,0b101101110,0b110101101,0b110100100,0b101100101,0b111111111,0b111110111,0b111111111,0b101100101,0b101101101,0b101101101,0b110110111,0b100011100,0b110101110,0b101101110,0b100100101,0b101101110,0b110101111,0b11011101,0b101101110,0b101101110,0b101100101,0b101101110,0b110101110,0b110110111,0b101101101,0b110101110,0b100100101,0b100100101,0b100100101,0b100100110,0b100100101,0b101101110,0b100100101,0b101101110,0b111111111,0b101101110,0b110101101,0b111111111,0b111111111,0b110101110,0b111111111,0b111111110,0b111111111,0b111111111,0b111111111,0b111110110,0b101101100,0b110101101,0b101100110,0b110110111,0b11010110,0b11010111,0b11001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b100100111,0b111111111,
0b111111111,0b10010110,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b10010111,0b100011111,0b10010111,0b11011111,0b11011111,0b11011111,0b11011111,0b10010111,0b11011111,0b11011111,0b10010110,0b10010110,0b10010101,0b10010100, 0b1001100, 0b1001100,0b11011101,0b110101110,0b110101101,0b101100100,0b101100101,0b111110111,0b111110111,0b111110111,0b101100101,0b101101110,0b101100101,0b110110111,0b100100100,0b100100101,0b100100101,0b11011101,0b11100101,0b101100110,0b100100110,0b100100101,0b101101110,0b100100101,0b101100110,0b101101110,0b110110111,0b101101110,0b101101101,0b101100110,0b101101110,0b100101110,0b101101111,0b100100110,0b101101111,0b101100110,0b100100110,0b110110111,0b111110111,0b100100100,0b111110111,0b111110111,0b110101110,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100100011,0b110110110,0b101101101,0b100011101,0b110110111,0b100011111,0b11010110,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10001111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b10010111,0b10010111,0b10001111,0b11010111,0b110110111,0b111111111,
0b11010111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11001111,0b11010111,0b100011111,0b11010111,0b10010111,0b10010111,0b10001111,0b11010111,0b10010111,0b10010111,0b11010111,0b11011111,0b11011110,0b10010100,0b11100110,0b100101111,0b11100110,0b11100110,0b10011100,0b110111111,0b110111111,0b11100100,0b101101101,0b111110110,0b101100100,0b101100100,0b110110110,0b111110111,0b111110111,0b101101110,0b100100101,0b11011101,0b100100110,0b100011100,0b101101110,0b101101110,0b100101110,0b100101110,0b100100110,0b100100110,0b100100110,0b101101110,0b100100101,0b101100101,0b101101110,0b101101110,0b101101110,0b101101101,0b100101110,0b100100110,0b100100110,0b110110111,0b101101111,0b101101110,0b101101111,0b100100101,0b110110111,0b111111111,0b11010011,0b110110111,0b111110111,0b111111111,0b100100100,0b111111111,0b111110111,0b111111111,0b111111110,0b111111111,0b110101101,0b100100100,0b110110111,0b100011101,0b11010110,0b101101111,0b101101111,0b11010101,0b10010111,0b10001111,0b10001111,0b10010111,0b10001111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b101101111,0b110110111,
0b11010111,0b11001111,0b11001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11001111,0b11010111,0b101100111,0b11010110,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001110,      0b11,      0b10, 0b1010011,0b101110111,0b101111111,0b11101110,0b100110111,0b101110110,0b100101101,0b100101101,0b101100100,0b111110111,0b101100100,0b101100101,0b110101101,0b111111111,0b110110110,0b101101110,0b100100101,0b100100101,0b101100110,0b101100110,0b101100110,0b101101110,0b100100110,0b100101110,0b100100110,0b100100110,0b110110111,0b100100110,0b101100110,0b100100101,0b101101110,0b101101110,0b101101110,0b101100110,0b100101110,0b100101110,0b100101110,0b111111111,0b111111111,0b100100110,0b110110111,0b11100101,0b110110110,0b111111111,0b10010010,0b101100110,0b111110111,0b111110111,0b101101101,0b110101110,0b111110111,0b111111110,0b111111110,0b111110111,0b111111111,0b11011011,0b101101110,0b101101111,0b11010110,0b11010110,0b100011111,0b110110111,0b100011111,0b10001111,0b10001111,0b11010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11011111,0b101101111,
0b10001111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b10001111,0b10001111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111, 0b1000100,0b10001100, 0b1000011,0b10010011,0b100101110,0b101111111,0b10100100,0b11101110,0b11101110,0b110111111,0b101101110,0b100100100,0b111110111,0b101100100,0b101101100,0b101101101,0b111110111,0b110110111,0b110110111,0b100100101,0b101100101,0b100100110,0b101101111,0b100100110,0b100100110,0b100101110,0b101101111,0b100100101,0b100100101,0b111111111,0b101101110,0b100100101,0b101100110,0b100100110,0b100101110,0b101101110,0b101100110,0b100100110,0b101101110,0b10010010,       0b0,       0b0, 0b1001010,0b10010011,0b11011100,0b101101101,0b111111111,0b11010011,0b100011100,0b110110111,0b111111111,0b110110110,0b100011100,0b111111111,0b111110110,0b111110110,0b111110110,0b111111111,0b100011100,0b100011100,0b110101111,0b11010111,0b10001111,0b11010111,0b10010110,0b100011111,0b101101111,0b100011111,0b11010110,0b10010110,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b101100111,
0b10010111,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b101101111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010111,0b11010111,0b11010111,0b10001111,0b11010111,0b11010110, 0b1000100,0b10001100, 0b1001100,0b100011110,0b10011101,0b10011101,0b101110111,0b11100110,0b110111111,0b11011011,0b100100100,0b101100101,0b111110110,0b101100101,0b101101101,0b101100100,0b111110111,0b110110111,0b110110111,0b100100101,0b101101110,0b100101110,0b101101111,0b101101110,0b101101110,0b100100110,0b110111111,0b101110111,0b100100101,0b111111111,0b111111111,0b100101110,0b101101110,0b100100110,0b100100110,0b101101110,0b100100110,0b100100101,0b10001011,       0b0, 0b1000000, 0b1000000,0b10001010,       0b0,0b11011100,0b100100100,0b110110111,0b11010011,0b11010011,0b110110110,0b111111111,0b111110110,0b100011100,0b110110110,0b111110111,0b111110111,0b111110110,0b111111111,0b101100101,0b100011101,0b100100111,0b100100111,0b11010111,0b10001111,0b11010111,0b10010110,0b10010110,0b11011110,0b100011111,0b11011111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10001111,0b11001111,0b10010111,0b10010111,0b11001111,0b11001111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11001111,0b11001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b11010111,0b10010111,0b10001111,0b11010111,0b10010111,0b11010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b100100111,0b10010111,0b11001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010111,0b11010111,0b10001111,0b11010111,0b10001101,0b10001100,0b10001011,0b10001100, 0b1001100,0b10010101,0b10010110,0b10010101,0b10010100,0b11011011,0b101101101,0b101100100,0b101100101,0b110101110,0b110101110,0b100100100,0b110101110,0b110101110,0b110110111,0b110110111,0b100100101,0b101101110,0b101110111,0b11100100,0b10010011, 0b1001001,0b11011100,       0b1,0b11011100,0b110111111,0b110111111,0b111111111,0b111111111,0b101101110,0b101101110,0b100100110,0b101101110,0b101101110, 0b1000001,0b10000010,0b10001001,0b11001001,0b11001001,0b101100100,0b10010011, 0b1001010,0b11011100,0b110101110,0b11010011,0b11010011,0b101100101,0b111111111,0b111110111,0b100100101,0b101100100,0b111110111,0b111110111,0b111110110,0b111110110,0b101100110,0b100011110,0b11010101,0b101101111,0b11010101,0b11010111,0b11001111,0b11010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11001111,0b11001111,0b10010111,0b10010111,0b10001111,0b11001111,0b11001111,0b10010111,0b11010111,0b11001111,0b10001111,0b11010111,0b11001111,0b11001111,0b11001111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b11010111,0b11011110,0b110110111,0b101101111,0b11010111, 0b1001101, 0b1001011,0b11001100,0b10001100,0b10001101,0b10001101,0b10001101,0b10001101,0b100011100,0b100011011,0b110101101,0b110101101,0b101100100,0b110101101,0b110110110,0b100100101,0b110101110,0b110101110,0b110110111,0b110110111,0b101101110,0b11011011,       0b0,       0b0,       0b0,       0b0, 0b1000000, 0b1001001, 0b1001010, 0b1010011,0b110111111,0b111111111,0b111111111,0b111111111,0b110111111,0b100100101,0b100100110,0b100100110,0b100011100,0b10001001,0b100010010,0b100010001,0b100010010,0b110101101,0b10010011,0b11011100,0b11011100,0b101100101,0b11010100,0b11010011,0b100011100,0b111110110,0b111110111,0b101100101,0b11011011,0b110110111,0b110110111,0b110110110,0b111110110,0b110101110,0b100011110,0b11010101,0b101100110,0b11011110,0b11010110,0b11001111,0b11001111,0b10010111,0b10010111,0b10001111,0b10001111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b10010111,0b11010111,0b11010111,0b11001111,0b10001111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010110,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11001111,0b11010111,0b10010110,0b111111111,0b111111111,0b111110111,0b100100111,0b10001101,0b11010101,0b10000011,0b10001100,0b10001100,0b10001101, 0b1000100,0b10000011,0b11010100,0b100011100,0b11010011,0b101100100,0b101100101,0b101100100,0b111110110,0b101101101,0b101101110,0b110110110,0b110110111,0b110110111,0b110110111, 0b1001001, 0b1000001,0b10001010,0b10001010,0b10001001,0b11001001, 0b1000000,0b111111111,0b110111111,0b101110110,0b111111111,0b111111111,0b110111111,0b111111111,0b110110110,0b101101110,0b100100110,0b101101100,0b100011010,0b100011010,0b101100010,0b110101100,0b111111111,0b101101110,0b11010011,0b11011011,0b100011100,0b100010011,0b11010011,0b11010011,0b110110110,0b111110111,0b101101110,0b11011011,0b101101110,0b110101110,0b111110110,0b110110110,0b110101110,0b100011101,0b100011101,0b11011101,0b100100111,0b11010111,0b11001111,0b10001111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010110,0b100100111,0b101101111,0b11011111,0b10010110,0b100011111,0b101101111,0b100011111,0b10010110,0b10010110,0b100011111,0b11011111,0b11010110,0b101100111,0b101101111,0b11010110,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b11010111,0b11010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11001111,0b10001111,0b11010111,0b11010111,0b11001111,0b10001111,0b101100111,0b111111111,0b111111111,0b111111111,0b101100111,0b10001110,0b10001101,0b10001100,0b10001100,0b10001101, 0b1001100,0b10001100,0b11010101,0b101100101,0b101100101,0b100011100,0b100011100,0b100011100,0b101100101,0b110101110,0b101101101,0b110110110,0b101101101,0b110110111,0b110110111,0b110101110,0b11011011,0b10000001,0b11001010,0b11010010,0b11001000,0b101011010,0b10000000,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b100100011,0b110110100,0b111111101,0b100100011,0b111111111,0b111111111,0b10010011,0b11011011,0b100011011,0b100010011,0b100010011,0b11010010,0b101101101,0b111110111,0b101101110,0b11011100,0b100011100,0b110101110,0b111110110,0b110101110,0b111110110,0b100011101,0b100011110,0b11010101,0b100100111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b11001111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b100011111,0b111111111,0b101101111,0b111111111,0b11011110,0b111111111,0b110110111,0b111111111,0b100100111,0b110101111,0b111111111,0b101101111,0b110110111,0b111111111,0b110110111,0b111111111,0b10001110,0b11010111,0b10001111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b101100111,0b110110111,0b100100111,0b100011111,0b10010111,0b11010111, 0b1000100,0b10010101, 0b1000011, 0b1000100,0b10001100,0b10001100,0b100011101,0b110101110,0b11010011,0b100011100,0b110101110,0b11011100,0b100011100,0b101100101,0b110110110,0b101101101,0b110111111,0b110110111,0b110110111,0b110101110,0b101101110,0b10000000,0b100010010,0b100011010,0b100010001,0b110100010,0b111111110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b101110101,0b110110101,0b110110101,0b110110110,0b110111111,0b110110111,0b11010100,0b11011100,0b100010011,0b100010011,0b11010011,0b11010011,0b100100100,0b111110110,0b110101110,0b100011100,0b100011100,0b110101110,0b110101110,0b110101110,0b110110111,0b100011101,0b11011110,0b10010110,0b100011111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10001111,0b100011111,0b110101111,0b100100110,0b111111111,0b100100110,0b111111111,0b100100101,0b111111111,0b101101111,0b100100110,0b111111111,0b101101111,0b110110111,0b110110111,0b101101110,0b111111111,0b11010110,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11011111,0b100100111,0b10010111,0b11010111,0b10001111,0b10001111,0b10001111,0b10001111,0b11010111,0b11010111, 0b1001100,0b10001100,0b10001100,0b10001100,0b11010100,0b101101110,0b110110110,0b100011011,0b100011011,0b110101110,0b100100101,0b100011101,0b100011100,0b101101101,0b101101110,0b110110111,0b110110110,0b111110111,0b110110110,0b101110111,0b100011011,0b100011010,0b101100011,0b111110101,0b110101100,0b100100011,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110110111,0b11010011,0b100011100,0b100010011,0b100010100,0b11010011,0b11010011,0b100011011,0b110101110,0b110101110,0b101100101,0b100011100,0b101100101,0b110110110,0b110101110,0b110101110,0b100011101,0b11011110,0b11010110,0b11010111,0b11011111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010111,0b11010111,0b10010101,0b111111111,0b110110111,0b11011110,0b111111111,0b100100110,0b111111111,0b101101110,0b10010100,0b111110111,0b101101111,0b110110111,0b111111111,0b110101111,0b111111111,0b11010110,0b11010111,0b10001111,0b10010111,0b11010111,0b11010111,0b10001111,0b11010111,0b11010111,0b10010111,0b11010111,
0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b111110111,0b11010111,0b10010111,0b10001111,0b11010111,0b11001111,0b11001111,0b11010111,0b10001111,0b10010111,0b11010110,0b11010101,0b100011101,0b100011101,0b100011100,0b101100101,0b110110110,0b101101101,0b11011011,0b101100101,0b100100101,0b100100101,0b101100100,0b101100100,0b100101101,0b100101101,0b101101101,0b110110110,0b111110111,0b110110111,0b110110110,0b110101101,0b100100011,0b110110110,0b101101101,0b110110111,0b110111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b110110110,0b11010011,0b100011100,0b100010100,0b100010100,0b100011100,0b11010011,0b11010011,0b110101101,0b110101110,0b101100101,0b11010011,0b100011100,0b110101110,0b110101110,0b110101110,0b100011110,0b11010110,0b11010111,0b11010111,0b100011111,0b11010110,0b10010111,0b10001111,0b10010111,0b11010111,0b10001111,0b10010111,0b11010111,0b11001111,0b11001111,0b10001110,0b110101111,0b111111111,0b11010101,0b100011111,0b111110111,0b100100110,0b111111111,0b101101111,0b10010101,0b111110111,0b101101111,0b11011101,0b110101111,0b110110111,0b111111111,0b11010110,0b10010111,0b10001111,0b10010111,0b10010111,0b11010111,0b11001111,0b11010111,0b11010111,0b11010111,0b100011111,
0b10001111,0b10001111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10001111,0b10010111,0b11010111,0b10001111,0b10010111,0b101101111,0b11011110,0b11010110,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b100010101,0b100011101,0b100100100,0b101011101,0b101100101,0b110110111,0b101101101,0b101100100,0b11010100,0b101100110,0b100011100,0b101100100,0b101100100,0b100100101,0b100101110,0b110101110,0b10010010,0b100011100,0b101101111,0b101101110,0b101101110,0b111111111,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b110111111,0b110111111,0b111111111,0b110111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b110110110,0b11010010,0b100011100,0b100011100,0b11010011,0b101100101,0b11010011,0b11010011,0b110101101,0b110101101,0b101100110,0b11010100,0b100011100,0b110101110,0b110101110,0b101100101,0b100011101,0b11010110,0b11010111,0b10001111,0b11011111,0b10010110,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10001111,0b100011111,0b111111111,0b110110110,0b100011111,0b100010111,0b111110111,0b101101110,0b111111111,0b101101111,0b11010101,0b111111111,0b101100111,0b110110111,0b111110111,0b101101110,0b111111111,0b10010110,0b10001111,0b10001111,0b10010111,0b10010111,0b11010111,0b11001111,0b11001111,0b11010111,0b100100111,0b111111111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b11010111,0b11001111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11001111,0b11010111,0b11010111,0b11010110,0b100100110,0b100100100,0b101100101,0b100011101,0b110101111,0b101101101,0b110101101,0b101100101,0b100011101,0b11011100,0b100100101,0b100100100,0b110101110,0b110101110,0b101100101,0b110110110,0b100011101, 0b1001011,0b100100101,0b101101110,0b110111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b110111111,0b110111111,0b110111111,0b111111111,0b101101101,0b100011100,0b11010100,0b11011100,0b11010100,0b100100101,0b11010011,0b11011011,0b101100101,0b101100101,0b110101101,0b100011100,0b100010100,0b101100101,0b110101110,0b100100101,0b100011101,0b11010110,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b11010111,0b10010111,0b100011111,0b110101111,0b110101111,0b110101111,0b10010110,0b101100111,0b110110111,0b110101111,0b11010111,0b11010111,0b110101111,0b100011111,0b11010110,0b110110111,0b110110111,0b100011111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11001111,0b11010111,0b110110111,0b111111110,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b100011110,0b100100110,0b100011101,0b101100101,0b100011100,0b110101110,0b101101101,0b110110110,0b101100100,0b101101110,0b101101110,0b101101101,0b100100101,0b101100101,0b111110111,0b110110110,0b110110110,0b101101110,0b101100110,0b110110111,0b110110111,0b101101110,0b110111111,0b110111111,0b110111111,0b110111111,0b111111111,0b110111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b111111111,0b100011100,0b101011100,0b11010100,0b100011101,0b100011101,0b100010100,0b100011011,0b100010011,0b101100101,0b100011101,0b101100110,0b11010101,0b11010101,0b100011101,0b110101110,0b100100101,0b100011110,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010110,0b10010110,0b10010110,0b11010111,0b10010110,0b10010110,0b11010110,0b11010111,0b11010111,0b10010110,0b11001111,0b11010110,0b10010110,0b10010110,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b110110111,0b110111111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b100011111,0b100011110,0b100011101,0b100011101,0b100011101,0b101101110,0b101101110,0b110101110,0b101100100,0b101100100,0b101101110,0b100100100,0b101100101,0b100011011,0b111110110,0b111110111,0b110110111,0b110110111,0b110110110,0b101100101,0b110101110,0b110110111,0b101110111,0b110111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b110110110,0b100011011,0b101100100,0b100010100,0b100011101,0b11010101,0b100010100,0b100011100,0b100010011,0b101100101,0b100011101,0b101100110,0b11011110,0b10010101,0b100011101,0b110101110,0b100011101,0b100011110,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10001111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b100011111,0b11010111,0b100011111,0b100011111,0b11010110,0b100011111,0b11010111,0b11010110,0b100011111,0b100011111,0b10010110,0b100011111,0b100011111,0b10001111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b100100111,0b100011111,
0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b11010111,0b10001111,0b10010111,0b10001111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b100011111,0b100011110,0b100011101,0b100011101,0b100011101,0b100011100,0b110101110,0b101100101,0b101100101,0b110101101,0b11010011,0b100011011,0b100011100,0b100011011,0b10001010,0b100100101,0b110110111,0b111111111,0b111111111,0b110101110,0b100100101,0b101101110,0b101101110,0b101110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100011100,0b100011100,0b101011100,0b11011100,0b11011101,0b11010101,0b11010100,0b11011100,0b11010011,0b101100101,0b11010100,0b100011100,0b100011101,0b11010101,0b11011100,0b110101101,0b101011101,0b11010110,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010111,0b11010111,0b10001111,0b10001111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11011111,0b100100111,0b11010110,0b100011111,0b10001110,0b100011111,0b100011111,0b11011111,0b11011111,0b100011111,0b100011111,0b100011111,0b10010110,0b100011111,0b10001111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,
0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11001111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b100011110,0b100100110,0b100011101,0b100011101,0b100011101,0b100100101,0b101100110,0b110101110,0b101100101,0b100011011,0b100011011,0b100011100,0b101100101,0b100011100,0b11010011,0b10001011,0b101101110,0b110110110,0b110110110,0b101101110,0b101101110,0b101101110,0b101110110,0b101110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100011100,0b100011100,0b100011100,0b100100101,0b100100110,0b100100110,0b100100110,0b101101110,0b100101110,0b100100101,0b101100101,0b11001010,0b100010010,0b11010011,0b100011100,0b100011100,0b101100100,0b101011100,0b100011101,0b11011110,0b10010110,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b11011111,0b100100111,0b100100111,0b11011111,0b11011111,0b100011111,0b11011111,0b11011111,0b11011111,0b100011111,0b11011111,0b11011110,0b100100111,0b10010111,0b11001111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b100011111,
0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11001111,0b10010111,0b10010111,0b10010111,0b110101111,0b11011111,0b10001111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010110,0b100011111,0b11011110,0b100011101,0b100011101,0b100011101,0b100011101,0b100100101,0b110101110,0b101100101,0b100011100,0b100011100,0b100010011,0b101011100,0b101100101,0b100011101,0b100011101,0b110101110,0b110110111,0b110110110,0b110110110,0b101101110,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b110110111,0b11010011,0b100011100,0b100011100,0b11010100,0b101101110,0b101101110,0b101101110,0b100101101,0b11100101,0b11100101,0b100100101,0b100100100,0b100011011,0b101011011,0b110101101,0b110110110,0b100011100,0b101100100,0b100011100,0b101101110,0b110110111,0b111110111,0b110100111,0b11010110,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010110,0b100011111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10010111,0b11010111,0b100100111,0b100100111,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b100011111,
0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010110,0b11010111,0b11001111,0b10010111,0b11010111,0b11010111,0b100011111,0b10010111,0b10010111,0b10001111,0b10010110,0b101100111,0b100011110,0b11010111,0b10001111,0b10001111,0b100011111,0b100011111,0b11010110,0b100011101,0b100011101,0b11011101,0b100011101,0b100011101,0b101100101,0b101101110,0b100011101,0b100011100,0b100011100,0b100010011,0b101100100,0b101100101,0b101100101,0b110101110,0b110101110,0b110110110,0b110101110,0b110101110,0b101100110,0b101101110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b110111111,0b111111111,0b101101101,0b11011011,0b100011100,0b11010100,0b100011101,0b110111111,0b110110111,0b101110110,0b110110110,0b111111111,0b111111111,0b100101110,0b101101110,0b111111111,0b111111111,0b101101101,0b100100101,0b101101110,0b100011100,0b101100100,0b100011011,0b100101101,0b101101110,0b101100100,0b111100100,0b110011100,0b11010101,0b10010111,0b10001111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b11010111,0b11010111,0b10010111,0b11010111,0b10010111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,
0b10010111,0b10001111,0b10001111,0b10010111,0b11010111,0b11010111,0b11001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010110,0b110110111,0b11010111,0b11001111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b100011111,0b111111111,0b100011101,0b11010111,0b10001111,0b10001111,0b11010111,0b11011111,0b10010111,0b11010110,0b100011101,0b100011101,0b100011101,0b100011101,0b100011101,0b101100110,0b101100101,0b11011100,0b100011100,0b100011100,0b100011100,0b100011100,0b101100101,0b100011100,0b110101110,0b110101110,0b110101110,0b101101101,0b101101110,0b101101110,0b100101110,0b101101110,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b110111111,0b11011100,0b100011100,0b100011100,0b100011100,0b11010100,0b100100110,0b11011101,0b100101110,0b110111111,0b111111111,0b111111111,0b111111111,0b110110111,0b101110110,0b111111111,0b111111111,0b101110111,0b100101110,0b100100101,0b100011100,0b100011100,0b100100100,0b100101110,0b110111111,0b110110110,0b101011001,0b101010001,0b100010010,0b11010101,0b11010111,0b10010111,0b11010111,0b10010111,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11001111,0b10001111,0b11010111,0b10001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b11001111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b11010111,
0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b10010111,0b11010111,0b10010111,0b10010111,0b10001111,0b101101111,0b101100111,0b10001110,0b11001111,0b11010111,0b11010111,0b11010111,0b11001111,0b10001111,0b10010111,0b10010101,0b111111111,0b110101110,0b101100110,0b11010111,0b10001111,0b10001111,0b11001111,0b11010111,0b11010111,0b10010111,0b11010110,0b100011101,0b100011101,0b11010101,0b100011110,0b100100110,0b101101110,0b11011100,0b11011100,0b100011101,0b100010100,0b100011100,0b100011101,0b100011101,0b100100100,0b110101110,0b110101110,0b101100101,0b100100101,0b101101101,0b101101110,0b101101111,0b100101111,0b100101110,0b101101111,0b101110111,0b110111111,0b111111111,0b111111111,0b101101101,0b11011100,0b100011101,0b100011101,0b11010101,0b11010101,0b11010101,0b100011110,0b101101111,0b100100101,0b110110110,0b111111110,0b111111111,0b111111111,0b110111111,0b111111111,0b110111111,0b111111111,0b100110110,0b110110111,0b101100101,0b100100101,0b11011100,0b11011100,0b111111111,0b101110111,0b110111111,0b111111111,0b110100100,0b101010010,0b100010011,0b11010101,0b11010111,0b11001111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b11010111,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b100100111,0b10010111,0b10010111,0b11010111,
0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11001111,0b11010111,0b11010111,0b10010110,0b11010111,0b11001111,0b10010111,0b11010111,0b10010111,0b11010111,0b11001111,0b10001110,0b110110111,0b111111111,0b110101101,0b101100110,0b11010111,0b10010111,0b10001111,0b11010111,0b11010111,0b10010111,0b10001111,0b11010111,0b100011110,0b11011101,0b11010101,0b11010101,0b11011101,0b100100110,0b101100110,0b10010011,0b100011100,0b100011101,0b11010100,0b100011101,0b100011101,0b100011101,0b100011101,0b110101110,0b110101110,0b101100101,0b101100101,0b100101110,0b100100110,0b101101111,0b101101111,0b101101111,0b101101111,0b101101110,0b11100101,0b11011100,0b100011100,0b100011100,0b100010101,0b11010101,0b11010101,0b11010110,0b11010110,0b100011110,0b11010101,0b11010100,0b110110110,0b110110110,0b111111111,0b110111111,0b110111111,0b110111111,0b110110110,0b110111111,0b101110110,0b110101110,0b101100101,0b100100100,0b100100101,0b110110111,0b111111111,0b110111111,0b101111111,0b101110111,0b101100101,0b101010010,0b100010001,0b100011100,0b11010110,0b10001111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,
0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010110,0b10010110,0b11010111,0b11001111,0b10010111,0b10010111,0b10010111,0b11010111,0b11001111,0b11011111,0b111111111,0b111110110,0b111101101,0b101100110,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010110,0b11011110,0b11010101,0b11010101,0b11010101,0b11010110,0b100011110,0b100100110,0b11010100,0b100011101,0b100011101,0b11010101,0b11010101,0b11010101,0b100011101,0b100011101,0b101100110,0b110101110,0b100100101,0b101101110,0b101101111,0b11011101,0b101101111,0b101101111,0b101110111,0b101110111,0b11011101,0b11010101,0b11010101,0b100010101,0b100010101,0b11010101,0b10010110,0b10010110,0b10010110,0b100011110,0b10000011,0b10001011,0b101100110,0b111111111,0b111111111,0b101110111,0b101110110,0b110111110,0b110110110,0b110110110,0b110111111,0b110110111,0b100100100,0b110101110,0b101101101,0b110110110,0b111111111,0b111111111,0b110111111,0b101110110,0b101100101,0b101100100,0b110101100,0b100011100,0b10010101,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,
0b10001111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001110,0b110110111,0b10010101,0b110101111,0b101100111,0b10001111,0b11001111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010110,0b110101111,0b111111111,0b111110110,0b111110110,0b101100110,0b10010110,0b10001111,0b10001111,0b11010111,0b11010111,0b10010111,0b10010110,0b10010111,0b10010111,0b11010110,0b11010101,0b11010101,0b11010110,0b11010110,0b11010110,0b11011110,0b100011110,0b11010101,0b11010101,0b11011101,0b11010101,0b100011110,0b11010100,0b100011100,0b100011100,0b100100101,0b110101110,0b100100101,0b101101110,0b110110111,0b100100110,0b100100101,0b101101110,0b110110111,0b11011110,0b11010110,0b11010110,0b11010101,0b11010101,0b11010110,0b11010110,0b10010110,0b11010101,0b100011110,0b10001011,0b10001011,0b10001011,0b111111111,0b111111111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b101101110,0b11100110,0b10010110,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10001111,0b11010111,0b11001111,
0b11001111,0b11001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10001111,0b101100111,0b101101111,0b101101111,0b111111111,0b100011111,0b10010111,0b10001111,0b10010111,0b10001111,0b10001111,0b10010110,0b11011101,0b111111111,0b111110111,0b111110111,0b111110111,0b101100110,0b10010110,0b10001111,0b10001111,0b11010111,0b11010111,0b10001111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010110,0b11010110,0b11010110,0b11010110,0b11010110,0b11010111,0b11010110,0b11010110,0b11010101,0b11010101,0b11010100,0b100011101,0b111111111,0b110101110,0b100011101,0b100010101,0b100011101,0b101101110,0b101100101,0b101101110,0b110110111,0b110110111,0b101101110,0b100101111,0b11011110,0b10010110,0b11010111,0b10010110,0b11010110,0b11010110,0b10001100,0b11010101,0b11010100,0b100011101,0b10001011,0b10001011,0b10000010,0b111110111,0b111111111,0b111111111,0b110110110,0b110110111,0b101101110,0b11011100,0b101110110,0b110111111,0b111111111,0b111111111,0b111111111,0b110110111,0b100100111,0b10011101,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b101110110,0b100101110,0b10011110,0b10001110,0b11010111,0b10010111,0b10001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,
0b11010111,0b11001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010110,0b111110111,0b110110111,0b111111111,0b110110111,0b10010110,0b10010111,0b10010111,0b11010111,0b10001111,0b10001111,0b10010110,0b101101101,0b111111110,0b110110110,0b111110111,0b111110111,0b100011110,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010110,0b10010111,0b11010111,0b11001111,0b11001111,0b11010110,0b11010101,0b101101110,0b110110110,0b111111111,0b111111110,0b111111111,0b100011111,0b11010110,0b100011110,0b11011100,0b100011100,0b100100101,0b100100110,0b101101111,0b101110111,0b101110111,0b100101111,0b10011101,0b10010101,0b10001101, 0b1001100, 0b1001100,0b100011101,0b10001010,       0b0,0b101100101,0b10001011,0b10001100,0b10000011,0b100010100,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b101110111,0b101110110,0b110110111,0b110110110,0b111111111,0b111111111,0b10011101, 0b1001110,0b10010110,0b110111111,0b110111111,0b111111111,0b111111111,0b110111111,0b101110110,0b100110110,0b11100110,0b101100111,0b10010110,0b10010111,0b10001111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b11001111,0b11010111,0b10010111,0b100011111,
0b11010110,0b100011111,0b11010111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010110,0b110110111,0b111111111,0b111111111,0b110110111,0b11010110,0b11010111,0b11010111,0b11010111,0b10010111,0b10001111,0b100100111,0b111111111,0b110110110,0b110110110,0b110110111,0b111110111,0b100011110,0b11010111,0b11001111,0b11001111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10001111,0b10001111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010110,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b101100111,0b10001111,0b10010110,0b101101111,0b110110111,0b101101110,0b101101110,0b101101110,0b101101111,0b101101111,0b101110111,0b101110111,0b111111111,0b110110111,0b101101111,0b101101111,0b110110111,0b110110111,0b11010011, 0b1000001,0b101100101,0b10001011,0b10001100,0b10001100, 0b1000010,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b101110110,0b101110110,0b110110110,0b110111110,0b111111111,0b101101111, 0b1000100,0b10001101,0b100100111,0b10010100,0b10010100,0b111111111,0b110110111,0b101110110,0b101110111,0b100101110,0b101110111,0b10010101,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b11010111,0b10010110,0b110110111,
0b101101111,0b110101111,0b10001111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b101100111,0b111111111,0b111111111,0b111111111,0b111110111,0b11010110,0b11010111,0b10010111,0b11010111,0b10010111,0b10010110,0b110110111,0b111111111,0b110101110,0b110110110,0b110110111,0b110110111,0b11010110,0b11010111,0b11001111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b10001111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010110,0b110110111,0b111111111,0b110111110,0b110111110,0b111111111,0b111111111,0b11010110,0b10001111, 0b1001110,0b100101111,0b101110111,0b101110111,0b110110111,0b101110111,0b101110111,0b101110111,0b101110111,0b110110111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b110111111,0b101101110, 0b1000001,0b101100110,0b10001100,0b11001101,0b10001100,0b10001011,0b100011100,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b101111111,0b101110111,0b101110110,0b101110111,0b100100101,0b11011100,0b10001011,0b10001100, 0b1000100,0b10001101,0b100100110,0b111111111,0b110110111,0b101101110,0b101110110,0b101110110,0b101110101,0b10011101,0b10001110,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b11001111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11001111,0b11010111,0b101101111,0b101101111,
0b110110111,0b10010110,0b10001111,0b11010111,0b10010111,0b11001111,0b11001111,0b11011110,0b111111111,0b111111110,0b110110111,0b111110111,0b100011111,0b11010111,0b11010111,0b11001111,0b10001111,0b10010110,0b101101111,0b110111111,0b110110111,0b110101111,0b101101110,0b101101110,0b110101111,0b11010110,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11001111,0b11001111,0b11010111,0b10010111,0b10010111,0b11001111,0b11001111,0b10010111,0b11100110,0b101110110,0b111110110,0b111111111,0b111111111,0b111111111,0b111111111,0b101101111,0b100101110,0b110111111,0b110111111,0b111111111,0b110110110,0b101110111,0b101110111,0b110110111,0b110110111,0b110110111,0b101110111,0b101110111,0b110110111,0b110111111,0b110110111,0b110111111,0b110111111,0b110111111,0b111111111,0b10010010,0b101100110,0b10001100,0b11010110,0b10010101,0b10001011, 0b1000010,0b111110111,0b111110111,0b111111111,0b111111111,0b111111111,0b101111111,0b110111111,0b110110110,0b110110111,0b10010100, 0b1001100,0b10001100,0b11001100,0b11010101,      0b11,0b110110111,0b111111111,0b111111111,0b101110110,0b110110110,0b110110110,0b101110111,0b100101110, 0b1001011,0b11010110,0b11010111,0b11001111,0b11010111,0b10001111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10001111,0b11010111,0b11010111,0b11010111,0b10001111,0b11010111,0b110110111,0b101101111,0b10010111,0b10001111,0b10001111,0b11010110,0b11010101,0b111110111,0b101101110,0b110101111,
0b11010110,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10001111,0b101101111,0b111110111,0b101101111,0b11011110,0b11011111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b11010110,0b111111111,0b110111111,0b110110111,0b101101110,0b101101110,0b101101110,0b101100111,0b11010110,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b100011111,0b110111111,0b110110110,0b111111110,0b111111111,0b111111111,0b111111111,0b111110110,0b101110111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b110111111,0b101110111,0b110110111,0b110110111,0b110110111,0b110110111,0b101110111,0b101110111,0b101110111,0b110110111,0b110111111,0b110111111,0b110111111,0b110111111,0b101101110,0b100011110,0b11001101,0b11010110,0b11011110,0b10010101,0b10001011,0b11010100,0b111111111,0b110111111,0b110111110,0b111111111,0b101111111,0b110111111,0b111111111,0b110110110,0b110110111,0b11011101, 0b1001011, 0b1000011, 0b1000011,0b10010101,    0b1011,0b100101101,0b110110111,0b101110110,0b101110110,0b110110110,0b101110111,0b101110110, 0b1001010,0b11010110,0b11010111,0b11010111,0b10010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b11010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b100100111,0b111111111,0b100100111,0b10010111,0b10001111,0b100011111,0b11010101,0b110110111,0b111111111,0b110110111,0b111111111,
0b11010111,0b11010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010110,0b110101111,0b11010111,0b10001111,0b10001111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b101101111,0b111111111,0b111111111,0b110111111,0b101101110,0b101101110,0b101101110,0b100100111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010110,0b100100110,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111110111,0b110101110,0b101101110,0b110111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b110111111,0b111111111,0b110111111,0b110111111,0b111111111,0b100011110,0b11010101,0b11010110,0b11011110,0b11011110,0b11010101,0b10000011,0b110101110,0b111111111,0b110111111,0b110110111,0b110111111,0b111111111,0b111111111,0b110111110,0b110110110,0b101110111, 0b1010100,0b10001101,0b11011111,0b10011101,0b10010100,0b100101110,0b101110110,0b101110111,0b101110111,0b101110110,0b100110111,0b110111111,0b11100100,0b10010100,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b11010111,0b11001111,0b10010111,0b10010110,0b101101111,0b110110111,0b100011110,0b11010110,0b100100111,0b101100111,0b101101111,0b111111111,0b111111111,0b111111111,0b111111111,
0b10001111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010110,0b110110111,0b111111111,0b111111111,0b111111111,0b110110111,0b101101110,0b110101111,0b100011111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010110,0b100100111,0b110110111,0b110110111,0b11100101,0b11011101,0b111110111,0b110101110,0b110101101,0b101100101,0b110110111,0b110111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b111111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b111111111,0b100100110,0b11010101,0b10010101,0b11011110,0b11011110,0b100011110,0b11010101,0b10010011,0b111111111,0b110110110,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b110111110,0b101110110,0b11100110,0b10011110,0b10010101,0b10011101,0b100100101,0b110110111,0b101110110,0b101110110,0b110110111,0b101110111,0b101110111,0b101110111,0b110110110,       0b1,0b11011110,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b11010111,0b10001111,0b10010111,0b10010111,0b101101111,0b110110111,0b110101111,0b11011101,0b110110111,0b101101111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,
0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111, 0b1010101,0b101101111,0b111111111,0b111111111,0b111111111,0b111111111,0b110101110,0b101101111,0b11010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10001111,0b10010111,0b11010111,0b11010110,0b101011110,0b110110111,0b110110111,0b101101111, 0b1001100, 0b1010101,0b101101111,0b110101110,0b111110110,0b101100101,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b110111111,0b110111111,0b111111111,0b100100101,0b11010101,0b11010101,0b11011110,0b11011110,0b11011110,0b11011110,0b10001100,0b101100110,0b111111111,0b110110110,0b111111111,0b110110111,0b101110111,0b100101111,0b101110111,0b101110110,0b110111111,0b101110111,0b100100110,0b11011101,0b101101110,0b101101110,0b101101110,0b101101110,0b101101110,0b101101110,0b100101110,0b101110111,0b101110111, 0b1001010,0b11011101,0b11010101,0b11010111,0b10010111,0b10001111,0b11010111,0b10010111,0b10001111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b101100111,0b110110111,0b110110111,0b110110111,0b111111111,0b100100110,0b110110111,0b111111111,0b101101111,0b110110111,0b111111111,
0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111, 0b1001101,0b101101111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b110101111,0b11011111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b100011110,0b110110111,0b110110110,0b100100101,0b100011110,0b100100111,0b11011110,0b11011101,0b101100101,0b110101111,0b11011100,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b110111111,0b110111111,0b111111111,0b111111111,0b110111111,0b101110111,0b101110111,0b101110111,0b110111111,0b101101110,0b11010101,0b11010110,0b11010110,0b11011110,0b11011110,0b100011111,0b11010110,0b10001011,0b111111111,0b110111110,0b110111111,0b100100101,0b10011101,0b11011110,0b100101111,0b110111111,0b110111111,0b110110110,0b101110110,0b101110110,0b101101110,0b101101110,0b101101110,0b101101110,0b101101110,0b101101110,0b101110101,0b100101110,0b101101110,0b11100101,       0b1,0b10010011,0b10010101,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010110,0b101100111,0b111111111,0b111111111,0b111111111,0b101100111,0b11011110,0b110101111,0b11011111,0b11011110,0b110110111,0b111111111,
0b10010111,0b10001111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111, 0b1010100,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110101111,0b100100111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b11010110,0b10010111,0b10010111,0b11010110,0b101101111,0b110111111,0b110111111,0b11011101,0b11010101,0b11001101,0b11010101,0b11011101,0b101101111,0b10010100,0b100100101,0b101101110,0b100100101,0b101110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110110111,0b101110111,0b100101111,0b101101111,0b11011101,0b11010101,0b11011110,0b11011110,0b11011111,0b100011111,0b100011111,0b10010100,0b100011101,0b111111111,0b110110110,0b110110111,0b11011101,0b10011101,0b101110111,0b110110111,0b111111111,0b111111111,0b110110110,0b101101110,0b100101110,0b101101110,0b101101110,0b101101110,0b101101110,0b101110111,0b101110101,0b101110110,0b101101110,0b101101110,0b10011100,    0b1010, 0b1001010, 0b1001011,0b11010101,0b11010110,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010111,0b11011110,0b111111111,0b111111111,0b111111111,0b100100111,0b10010110,0b11010111,0b11010111,0b10010111,0b100011111,0b111110111,0b111111111,
0b10010111,0b11010111,0b10010111,0b11001111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b11011111,0b11100110,0b101101110,0b111111111,0b111110110,0b111110110,0b111111111,0b111111111,0b110110110,0b101101111,0b11010110,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b11010111,0b110110111,0b10010111, 0b1001110,0b101101111,0b111111111,0b110111111,0b110110111,0b11010101,0b11010101,0b11001100,0b100011110,0b11011110,0b11011110, 0b1001100, 0b1001011, 0b1001010, 0b1001010, 0b1001010, 0b1000001,0b10010010,0b101100101,0b110110110,0b101110110,0b101110111,0b101101110,0b101100101,0b101100101,0b101100100,0b100100100,0b100100101,0b101100101,0b101101101,0b110110101,0b110110110,0b110110110,0b110110110,0b110110111,0b101101111,0b11011101,0b11010101,0b11011110,0b100011111,0b11011110,0b100011111,0b100011111,0b11011110, 0b1001011,0b110101111,0b111111111,0b110111111,0b111111111,0b110110111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b110110110,0b110110111,0b110110111,0b111111111,0b111111111,0b100101111,0b100101111,0b111111111,0b101110111,0b110111111,0b110111111,0b110111111,0b110111111,0b100101101,0b10010010,       0b1,0b11010110,0b11010111,0b11001111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10001111,0b10010111,0b110110111,0b111111111,0b111111111,0b110110111,0b11010111,0b10001111,0b10001111,0b10010111,0b10010110,0b101101111,0b111110111,0b111111111,
0b10001111,0b10010111,0b11010111,0b11010111,0b100011111,0b11010111,0b11010111,0b11010111,0b10001111,0b10001111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010110,0b11011111,0b100100110,0b101101110,0b110110110,0b110110110,0b110101110,0b110110110,0b111110111,0b110101110,0b110101111,0b11010110,0b11010111,0b11001111,0b10001111,0b11010111,0b10010111,0b110101111,0b100100111,0b10010110,0b11011110,0b110110111,0b111111111,0b111111111,0b101100111,0b10001101,0b11010101,0b100010110,0b10001101,0b10010110,0b10001101, 0b1001011, 0b1001001, 0b1001010, 0b1000001, 0b1001001, 0b1001010, 0b1000001,       0b0,       0b1, 0b1001010, 0b1001010,0b10010011,0b11010011,0b11010011,0b11010011,0b100011011,0b100011100,0b100011100,0b100010100,0b100010010,0b101011010,0b111101100,0b111110100,0b110101100,0b110110101,0b101101110,0b11011101,0b11011110,0b100100111,0b100011111,0b11011110,0b11011111,0b11011110,0b10001100,0b11010100,0b111111111,0b110110111,0b110111111,0b111111111,0b111111110,0b110111111,0b101110111,0b101111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100100110,0b10011111,0b100100111,0b100101111,0b110111111,0b110111111,0b111111111,0b111111111,0b101111111,0b110111111,0b10011100,0b10010100,0b11010111,0b11001111,0b10001111,0b11001111,0b10010111,0b10010111,0b11010111,0b10001111,0b10001111,0b11010111,0b111110111,0b111111111,0b111110111,0b100100111,0b10010111,0b10001111,0b10001111,0b10010111,0b11011111,0b110110111,0b111111111,0b111111111,
0b10001111,0b10010111,0b10010110,0b101100111,0b10001111,0b11010111,0b11010111,0b10010111,0b10010111,0b10001111,0b11010111,0b10010111,0b10001111,0b10010111,0b11011111,0b10010101,0b101101111,0b110110111,0b110110111,0b111110111,0b111110110,0b111110110,0b111101110,0b111101111,0b110101111,0b11010110,0b11010111,0b10010111,0b10001111,0b11010111,0b11010111,0b11010111,0b10010110,0b100100111,0b101110111,0b110111111,0b111111111,0b111111111,0b100100110,0b11010101,0b11010101,0b10001101,0b10010110,0b10010110,0b10001011,0b10001010,0b111111111,0b100101101,0b10010010, 0b1001001,0b100100101,0b101101110, 0b1001001,0b11010100,0b11011101, 0b1000010, 0b1000010,0b10000010,0b10001010,0b11010011,0b10001010,0b11010010,0b11010010,0b100011100,0b101011011,0b111101100,0b111110100,0b111101011,0b111101011,0b110101100,0b101100100,0b101100110,0b11011101,0b100100111,0b100011111,0b11011110,0b11011110,0b11010110,0b11001100,0b11001011,0b110101110,0b110110111,0b110110111,0b111111110,0b111111110,0b110110111,0b101110111,0b101110111,0b110111111,0b111111110,0b111110111,0b110110111,0b110110111,0b111111111,0b100100110, 0b1001101,0b10010110, 0b1010101,0b100101111,0b101101110,0b110110111,0b110110110,0b101110110,0b110111111,0b101110111,0b11011110,0b10010110,0b10010110,0b11010111,0b11010111,0b11001111,0b10010111,0b11010111,0b10001111,0b10001111,0b100011111,0b110101111,0b101101110,0b110110111,0b11011110,0b10010111,0b10010111,0b10010111,0b10010111,0b101101111,0b110110111,0b111111111,0b111111111,
0b10010111,0b11010111,0b101100111,0b11010111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b11010111,0b10010111,0b10001111,0b11010111,0b10010111,0b10010101,0b11100110,0b110110111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110111,0b110101110,0b100011110,0b11010111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b11010110,0b110101111,0b110110111,0b110111111,0b110111111,0b100101110,0b100101101,0b110110111,0b11010110,0b10010111,0b10010111, 0b1010100,0b10010010, 0b1001001, 0b1001001,0b10010011,0b10011011,0b100101101,0b100100101,0b101110111,0b10011100,0b10010100,0b10010101,0b10010100,0b10010101,0b11011101,0b10001010,0b10001001,0b11010011, 0b1000001,0b10001010, 0b1001001,0b10001010,0b10001001,0b11001001,0b11010010,0b100010010,0b100010010,0b100010010,0b100011100,0b100011110,0b100100111,0b100100111,0b11100110,0b11011110,0b10010101,0b10001101,0b11001100,0b11011100,0b111111111,0b110110110,0b111110110,0b110110111,0b110110111,0b101110111,0b110110111,0b110110110,0b110110111,0b101110111,0b101110111,0b101110111,0b110110111,0b101100110,0b10010101, 0b1010101,0b11101110,0b100101110,0b110110110,0b111110111,0b111110111,0b110110110,0b101110110,0b101110111,0b100101110,0b11100110,0b11100101,0b10010100,0b11010110,0b11010111,0b10010111,0b11010111,0b10001111,0b11010111,0b11011111,0b11011110,0b110110111,0b11011111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b101101111,0b110110111,0b111111111,0b110110111,
0b10010110,0b110101111,0b110110111,0b11010110,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10001111,0b10001111,0b10001111,0b101101111,0b110111111,0b110110110,0b111110111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110111,0b110101110,0b100011110,0b11010111,0b11010111,0b10010111,0b11011111,0b10010111,0b10010111,0b100011110,0b110101111,0b111111111,0b111111111,0b101110111,0b100101101,0b100101101,0b11011110,0b10010111,0b10001111,0b10010101,0b11100100,0b10010010, 0b1000000, 0b1001010,0b11011011,0b110111111,0b111111111,0b110110111,0b101110110,0b11100110, 0b1010100, 0b1001011, 0b1001100, 0b1001101, 0b1001100,0b10001010,0b10010001,0b11011011,       0b1, 0b1001001,0b10010001, 0b1001010,0b10010011, 0b1001010, 0b1001011,0b10001011,0b11001010,0b100010011,0b100010011,0b101011110,0b11011111,0b100100111,0b100100111,0b100100111,0b10010101,0b10001101,0b11001100,0b10001011,0b111111111,0b110101110,0b110110110,0b110110111,0b110110111,0b110110111,0b110110110,0b110110110,0b101110111,0b100110111, 0b1011100,0b101110111,0b110110110,0b110110111,0b110110111,0b100100101,0b101110110,0b110110111,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b110110111,    0b1010,0b100101110,0b100101101,0b11011011, 0b1001011,0b10001100,0b10010110,0b11010110,0b11010111,0b10001111,0b10010111,0b101100111,0b11010111,0b10001111,0b10001111,0b10001111,0b11010111,0b10010111,0b11010111,0b100100111,0b110101111,0b110110111,0b110110111,
0b100100110,0b111111111,0b111111111,0b11010110,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b100011111,0b111111111,0b101110110,0b110110110,0b111110111,0b110110110,0b101101100,0b110110101,0b110110110,0b111110110,0b111110111,0b110101111,0b11010110,0b11001111,0b11010111,0b100100111,0b110110111,0b10010101,0b100100111,0b100011110,0b110101111,0b111111111,0b111111111,0b110101110,0b110110111,0b100100110,0b10010110,0b10010111,0b10001110, 0b1001011, 0b1001001, 0b1001001,0b11010011, 0b1001010,0b10010011, 0b1011011,0b10011011,0b11011011,0b101110111,0b100101110, 0b1010100,0b10001100,0b10010101, 0b1001101, 0b1001100,0b10010010,0b10001001,0b10010011,    0b1010, 0b1001001,0b10010001,0b10010011,0b10010011,0b10010011, 0b1010010, 0b1001010,0b101100101,0b10001010,0b11010011,0b11010100,0b101100111,0b100100111,0b11100111,0b100100111,0b100100111,0b11010101,0b10001101,0b10001100,0b100100101,0b111111111,0b110110110,0b101101110,0b110110111,0b110110111,0b110110110,0b110110110,0b110110111,0b100101110,0b101110111,0b101110110,0b110110110,0b101110110,0b101110111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110111111,0b110111111,0b111111111,0b101101110,    0b1010,0b100100101,0b110111111,0b11100101,0b10011100, 0b1001010, 0b1001001,0b11011101,0b10010110,0b10010111,0b11010111,0b11010111,0b10001111,0b11010111,0b10001111,0b10001111,0b10001111,0b10001111,0b11010111,0b11011110,0b110110111,0b110110111,0b100100110,
0b111111111,0b111111111,0b111111111,0b11011110,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010110,0b101101111,0b111111111,0b110110110,0b110101110,0b111110111,0b110110101,0b101101100,0b110110101,0b111110110,0b111110110,0b111110111,0b110101111,0b11010110,0b110101111,0b100011110,0b111111111,0b110110111,0b110110111,0b100011111,0b100100110,0b110101111,0b110101110,0b111110110,0b110101110,0b101011110,0b10001111,0b10010111,0b10010110,0b11011101,0b11011100,0b10010010,0b10010010,0b11011011,0b101110110,0b101101110,    0b1001,0b10010011,0b100100100,0b111111111,0b111111111,0b100100101,0b10010100, 0b1001100,0b10001100,0b10010100,       0b1,0b10010011, 0b1001010,0b10010011, 0b1000001,0b11010001,0b10001001,0b10001001, 0b1001001,0b11011011, 0b1001000,0b10011011,0b10010100,       0b1,0b10001010,0b11010011,0b100100110,0b11100111,0b11100111,0b100100111,0b100100111,0b11010110,0b10001101,0b10001011,0b111111111,0b110110110,0b110110110,0b110101110,0b110110111,0b110110111,0b110110110,0b110110111,0b110110111,0b110110110,0b110110111,0b110110110,0b101101110,0b101101110,0b111111111,0b111111111,0b111110110,0b111111111,0b101110110,0b101110110,0b110111111,0b111111111,0b110110111,0b100101110,0b10010100,0b110111111,0b110111111,0b101111111,0b11100100, 0b1001000,    0b1010,0b100100110,0b11010110,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b100011111,0b101101111,0b110101111,0b100011111,
0b111111111,0b111111111,0b111111111,0b100100111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010110,0b111111111,0b111111111,0b101101110,0b110101110,0b111110110,0b110110110,0b110110110,0b101110110,0b110110111,0b111110111,0b111110111,0b10001110,0b101100111,0b111111111,0b110110110,0b111111111,0b111111111,0b110101111,0b10001110,0b101100110,0b110101110,0b110101101,0b110100101,0b101011110,0b11001111,0b10010111,0b10010111,0b101100110,0b100011100,0b11011011,0b11011100,0b10010011,0b10010011,0b11011011,       0b0, 0b1010011,0b101101110,0b10010011, 0b1001001,0b101101101,0b10010011, 0b1010011, 0b1001011, 0b1001010,0b10001010,0b100100100,0b11011100,0b10010011, 0b1001010, 0b1000001,0b10001001,0b10000000, 0b1000000, 0b1001001,0b11010010,0b10001000, 0b1000001,0b10011100, 0b1001010, 0b1000001,0b10000001,0b10001010,0b100100110,0b100100110,0b100100111,0b100100111,0b100011111,0b11010110,0b10001101,0b10010100,0b111110111,0b111111111,0b111111111,0b110110110,0b110110110,0b110110110,0b110110110,0b111110111,0b111110111,0b111110111,0b110110110,0b101110110,0b101110110,0b110110110,0b101101101,0b110110110,0b101110110,0b110111111,0b111111111,0b111111111,0b111111111,0b110110110,0b110110111,0b110111111,0b110110111,0b101111111,0b110111111,0b101111111,0b100101101,       0b1,0b10010100,0b10010100,    0b1011, 0b1001100, 0b1000100,    0b1011, 0b1001011, 0b1001100, 0b1001101, 0b1010110,0b10010110,0b10010110,0b101101111,0b101101111,0b100011111,
0b111110111,0b111111111,0b111110111,0b100011110,0b11010111,0b10001111,0b10001111,0b10010111,0b10010111,0b11001111,0b11001111,0b11010111,0b11010110,0b111111111,0b111111111,0b101101110,0b110101110,0b110101110,0b110110110,0b110110111,0b101110111,0b110110111,0b110110111,0b11010101,0b10010110,0b101101111,0b111111111,0b111111110,0b111111111,0b111111111,0b11011111,0b10001111,0b101100101,0b110101110,0b110101110,0b101011110,0b11010111,0b10001111,0b10010111,0b100011110,0b111110111,0b111101101,0b101100101,0b10010011, 0b1001010, 0b1001001,0b10001001,0b10001001, 0b1010011,0b10010011, 0b1001001, 0b1000000, 0b1000000, 0b1001001, 0b1010010, 0b1010011,0b10010010, 0b1001001,       0b0,       0b1,0b11100101,    0b1010,0b10010010,0b10001001,0b101011011,0b11011011,0b10010010, 0b1001001,0b10000001, 0b1000001,0b10010010,0b10010011, 0b1001001,0b10001000, 0b1000000, 0b1000001,0b11011101,0b100100111,0b11011111,0b11011111,0b100011110,0b11010110,0b10010101,0b10010100,0b100100100,0b111111110,0b111111111,0b111111111,0b111111111,0b111110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110111111,0b111111111,0b110111111,0b110111111,0b101110111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b110110110,0b110111111,0b110111111,0b101110111,0b101111111,0b110111111,0b101111111,0b110101111,0b11011100,0b11100100,0b11100101,0b100100101,0b100100101,0b100100101,0b100101101,0b100101110,0b100101111,0b100100111,0b100101111,0b11100111,0b100100111,0b100100111,0b10010111,
0b110110111,0b110111111,0b111111111,0b111111111,0b11010111,0b10001111,0b11011111,0b11010110,0b11010110,0b10001111,0b10001111,0b10001111,0b100100111,0b111111111,0b110111111,0b100101110,0b101101110,0b101101111,0b110101111,0b110110110,0b101110110,0b101110111,0b10010111,0b10001110,0b101101111,0b111111111,0b111111110,0b111111111,0b111111111,0b100011111,0b10010111,0b10001111,0b101100100,0b111101110,0b110100110,0b100011110,0b11010111,0b10010111,0b10010110,0b101101111,0b110110110,0b100011011,0b11011011, 0b1001001, 0b1001001, 0b1010010,0b10010011,0b10010011, 0b1001100,0b10001011,0b10001010,0b10010001,0b101101011,0b101100011,0b101100011,0b110101101,0b11011011,0b11100100,0b10011011, 0b1001010,0b11011011, 0b1010010,0b10001001,0b11010010,0b100011100,0b100011100,0b10010011,0b10010011,0b11011011,0b11001001,0b100010010,0b100011011,0b10010010, 0b1010011,0b100100101,0b10001001,0b10001001,0b10001001,0b100011100,0b101100110,0b11011111,0b11011110,0b11011110,0b11010110,0b11001101,0b10001100,0b11010101,0b100011101,0b110101110,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111110,0b111111110,0b111111110,0b111111111,0b111111111,0b101110101,0b110110110,0b110111110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b10011101,0b10011110,0b11011110,0b11100110,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,0b101110111,0b11100101,
0b110110111,0b111111111,0b111111111,0b111111111,0b11010101,0b100011111,0b110110111,0b11010110,0b11010111,0b10001111,0b11001111,0b10010111,0b101101111,0b111111111,0b111111111,0b101101110,0b101101110,0b110110111,0b101101110,0b110110110,0b101101110,0b100100111,0b10001111,0b10010111,0b110101111,0b111111111,0b111111111,0b111111111,0b101101111,0b10010110,0b10010111,0b10001111,0b100011100,0b101101101,0b101011101,0b100010110,0b11001111,0b10001111,0b11011111,0b110101111,0b100011011,0b100011100,0b11011100, 0b1001010,0b11011011,0b11011011,0b11010011,0b11011101, 0b1010011,    0b1011, 0b1001011,0b10010011,0b10011011,0b100100100,0b100100100,0b11100100,0b10011011,       0b1, 0b1001001,0b10010010, 0b1001010, 0b1001001, 0b1000000,0b11001001,0b101011100,0b100011100,0b11011011,       0b1,       0b0,0b101100100,0b101011010,0b11010010,0b100101101, 0b1010011,0b10010010,0b10001001,0b10001001, 0b1000001, 0b1000001, 0b1000001,0b11010100,0b100100110,0b100100110,0b100011111,0b100011111,0b100011110,0b11010101,0b10010100, 0b1001011, 0b1000011, 0b1001011,0b10001011,0b11010011,0b100011100,0b100100100,0b101100101,0b101100110,0b110101110,0b110101111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b110111111,0b111111111,0b110111111,0b111111111,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,
0b110111111,0b111111111,0b111111111,0b111111111,0b101101110,0b111111111,0b110110111,0b10010110,0b11010111,0b11010111,0b10001111,0b10010110,0b111111111,0b111111111,0b111111111,0b110101110,0b101110110,0b110110110,0b110101110,0b101101110,0b101101111,0b10010110,0b10001111,0b10001111,0b100100111,0b111111111,0b111111111,0b110110111,0b10010110,0b11010111,0b10010111,0b10010111,0b11011101,0b11010100,0b100011110,0b11010110,0b11010111,0b10001111,0b10010111,0b11011101,0b10010010,0b11010011, 0b1010011,    0b1010, 0b1001001,0b10010010,0b11011100,0b10011100, 0b1010011, 0b1010011,0b11100110,0b100101111,0b11100111,0b100101110,0b100101110,0b100101110,0b100101110,0b100101110,0b10010011,       0b0,0b100100100, 0b1000001, 0b1000000,0b11010010,0b101011100,0b100011011,0b100100100,       0b1,       0b1,0b10001001,0b11010001,0b110101101,0b101101110,0b100101101,0b10010010, 0b1001001,0b10001001, 0b1000001, 0b1001001, 0b1001001, 0b1000000,0b101101101,0b11100101,0b100100110,0b11100110,0b100100110,0b100100111,0b100100111,0b11011110,0b10001101, 0b1001100,0b10001100,0b10001100,0b10001011,0b10001011, 0b1001011,0b10001011, 0b1000011,0b10000011, 0b1000011,0b10000011,0b10000011,0b11001011,0b100010101,0b101100101,0b110101110,0b110110110,0b111111111,0b110111110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110110,0b101110110,0b101110110,0b110110110,0b110110110,0b111111111,0b110110110,0b110110111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100011111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010110,0b111111111,0b111111111,0b111111111,0b101100111,0b100011110,0b110101111,0b110110110,0b110110111,0b11011111,0b10001111,0b10001111,0b11010110,0b110101111,0b111111111,0b111111111,0b100100110,0b10010111,0b10001111,0b10010111,0b11010111,0b10010101,0b11010101,0b11001101,0b11010110,0b10010111,0b10010111,0b11010110,0b100011101,       0b1,0b10010010,0b10010010,0b11011011, 0b1001001, 0b1001010,    0b1010,0b100101110,0b101111111,0b110111111,0b101110111,0b11100110,0b10011101,0b101110111,0b101110111,0b100110110,0b100110110,0b101110110,0b110110111,0b100100101,0b11011100, 0b1001001, 0b1000000,0b100011011,0b101011100,0b101011100, 0b1001001, 0b1000001, 0b1001010,0b11010011,0b100011010,0b101100100,0b101101101,0b101101101,0b110110110,0b11010011, 0b1000001,0b100011100, 0b1001001, 0b1001000,       0b0,0b100100100,0b100100100, 0b1001001,0b100011101,0b101100111,0b100011110,0b100100110,0b100100111,0b100100111,0b11011110,0b10001100,0b10001100,0b10001100,0b10001100,0b10001100,0b10001011,0b10001011,0b10001011,0b11001100,0b11001011,0b10000011,0b10000010, 0b1000010,0b10001010,0b11010011,0b100011100,0b101101110,0b110110111,0b110110111,0b101101111,0b110111111,0b110110111,0b110101111,0b101101111,0b100100110,0b101100110,0b101101110,0b101101101,0b101101101,0b101101110,0b101101110,0b110110111,0b101101110,0b111111111,0b110110110,0b101101110,0b101101110,
0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b110101111,0b10001110,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b111111111,0b111111111,0b110110111,0b11011111,0b10001110,0b11011101,0b101101101,0b101101111,0b10010111,0b10001111,0b10001110,0b101100111,0b111111111,0b111111111,0b111111111,0b101101111,0b10010110,0b10001111,0b10010111,0b11010111,0b10001100,0b10001100,0b10001100,0b10010101,0b11011110,0b11011101,0b11010100, 0b1001010, 0b1001010,0b11011011,0b101100011,0b100011010,0b100100100,0b100101110,0b101111111,0b110111111,0b110111111,0b110111111,0b101110110,0b101110111,0b110110111,0b110110111,0b110110111,0b110111111,0b101110110,0b100101101,0b100100101,0b100101101,0b101101110,    0b1010, 0b1000001, 0b1001000,0b100011011,0b11010011,0b10010010,0b101101101,0b10010010, 0b1000001,0b100011011,0b100010011,0b101100100,0b100100100,0b100100100,0b10010011, 0b1000001,0b11011011, 0b1000000, 0b1001001,    0b1001,0b10010001,0b10010001,0b11010010,0b10001011,0b11010101,0b11010100,0b100011100,0b100011100,0b101100101,0b110101110,0b101101110,0b101100110,0b100100110,0b100011110,0b101011110,0b100100101,0b100011101,0b100011100,0b100011101,0b100011101,0b100100101,0b101101110,0b110110111,0b111111111,0b111110111,0b111110111,0b110101111,0b100100111,0b100011111,0b11011111,0b10010110,0b10001110,0b11010110,0b11010110,0b11010111,0b10010110,0b100100111,0b101101110,0b100101101,0b101101101,0b101101110,0b101101110,0b110110110,0b111111111,0b110110110,0b101101110,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b101101111,0b10010110,0b11010111,0b10001111,0b10001111,0b10010111,0b10010111,0b11010110,0b110110111,0b101101111,0b11011101,0b10010110,0b10001110,0b11011101,0b100100101,0b110110111,0b11010111,0b11010111,0b101101111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b101100111,0b110101111,0b10001111,0b11001111,0b11010100, 0b1000011,0b11011101,0b11011100,0b100100101, 0b1001001, 0b1001001, 0b1010010,0b11010010,0b100011011,0b100010010,0b101100100,0b101110110,0b110111111,0b110111111,0b110111111,0b101111111,0b110111111,0b111111111,0b111111111,0b110111110,0b110110110,0b110110110,0b110111111,0b110110111,0b101110111,0b101110110,0b101110111,0b101110110,0b110111111, 0b1001001,       0b0,0b10010010,0b10001010, 0b1001001,0b100100100,0b10010010,0b10001001,0b10001001,0b10001001, 0b1001001, 0b1001010,0b11011100, 0b1001001, 0b1001001, 0b1000001, 0b1001001, 0b1000000,0b101101101,0b10001001,0b100011011,0b100010011,0b11010101,0b100010101,0b11010011,0b10000000,0b10001000, 0b1000001, 0b1000001,0b10001001,0b10010010,0b11010010,0b11010010,0b11010010,0b10010100,0b100100110,0b100100110,0b100100110,0b100100110,0b100100110,0b100011110,0b11011110,0b11011101,0b11010101,0b10010101,0b11010110,0b11010110,0b11010111,0b11010111,0b11001111,0b11001111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010110,0b100100111,0b101110111,0b101101110,0b101101110,0b101101110,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b100011111,0b10010111,0b11010111,0b10001111,0b10001111,0b11010111,0b100100111,0b101101111,0b11011101,0b10010101,0b11011110,0b11010101,0b11010110,0b10010100,0b11011100,0b110110111,0b10010101,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b101101111,0b10010110,0b11001111,0b11011100,0b11011100,0b10010011,0b10001010, 0b1001001,0b11011011,0b100101101,    0b1000,0b101100100,0b100010011,0b110101101,0b110110110,0b110111111,0b110111111,0b110111111,0b110111111,0b101111111,0b110111111,0b111111111,0b110110110,0b110111111,0b110110111,0b110110111,0b110110111,0b111110111,0b110110111,0b101101110,0b101101110,0b110110110,0b110110110,0b111111111,0b100101100, 0b1000000,0b10010010, 0b1001001, 0b1001001, 0b1001001,0b10010010, 0b1001001,0b10010010,0b10010011,0b10011011,0b10010011, 0b1001010,0b10001010, 0b1000001, 0b1000001,0b10001001,0b11001010,0b100010011,0b11010011,0b11001100,0b11010110,0b100011110,0b11010011,0b10001000,0b10001001,0b10001001, 0b1001001, 0b1001000,0b10001000,0b10001000,       0b0,0b10001010,0b10010110,0b10010110,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010110,0b101100111,0b110110111,0b110110110,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b110110111,0b10001110,0b11001111,0b11001111,0b11010111,0b11010111,0b10001110,0b111110111,0b11011101,0b110110111,0b10010101,0b101101111,0b10001100,0b100011110,0b11011101,0b101100110,0b110110111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b11010101,0b11010110,0b11010111, 0b1001010, 0b1001010, 0b1000001,0b11011010,0b10001001, 0b1001010, 0b1001010,0b110111111,0b110110101,0b111110110,0b111111111,0b110111111,0b110111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b110110111,0b110110111,0b110110111,0b110111111,0b110110111,0b110110111,0b110110110,0b101101101,0b101101110,0b101101110,0b110110110,0b111111111,0b111111111,0b111111111,0b110110110,0b10010011, 0b1001010,0b10010011,0b11011100,    0b1001,0b10011011,0b111111111,0b101110110, 0b1001010, 0b1010010, 0b1001010, 0b1001010, 0b1001001,0b10001001,0b10001000,0b10001001,0b100011011,0b100100101,0b101100110,0b100011111,0b11011110, 0b1001011,       0b1, 0b1000000,0b10001010,0b10010010,0b10001001, 0b1000001, 0b1000001,0b11001100,0b11010110,0b10001111,0b10001111,0b10001111,0b10001111,0b10001111,0b11001111,0b11001111,0b11010111,0b11010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11001111,0b10001110,0b110110111,0b110110110,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b101101111,0b10010111,0b10001111,0b11001111,0b11010111,0b10010110,0b101100111,0b111111111, 0b1001100,0b100100111,0b101101111,0b11010101,0b100011101,0b100011110,0b10001011,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b11010110,0b11010110,0b10010101, 0b1000001, 0b1000001,0b11010010, 0b1001001,       0b0,0b100101110,0b100101111,0b100100110,0b110111111,0b110111111,0b110111110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110110,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111110111,0b111110111,0b111111111,0b111111111,0b10001011,0b10001011,0b10001011,0b10011100,0b110111111,0b111111111,0b111111111,0b11011011,0b111111111,0b111111111,0b11011100, 0b1000001,0b10001001, 0b1000000,0b11010011,0b101101101,0b110110110,0b101101110,0b11011100,0b100100111,0b10001100,0b10010100,0b110110111,0b101101110, 0b1000001,       0b1, 0b1001011,0b11010101,0b11010111,0b11001111,0b10001111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b101100111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b100101111,0b10010111,0b10001111,0b10001111,0b10010111,0b10010110,0b111111111,0b111111111,0b10001011, 0b1001100,0b11011111,0b11011110,0b11010100,0b10010101,0b100011101,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b10010110,0b100011111,0b11011111,0b11011110,0b11010010,0b10001001,0b10010011,    0b1001,0b101110111,0b11100110, 0b1001100,0b100101111,0b101110111,0b100110111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100100100,0b10001011, 0b1000010, 0b1001010,0b10000011,0b10000011, 0b1001010,0b11010011,0b110100110,0b10001100,0b11011101,0b101110111,0b101110110,0b111111111,0b110111111,0b110111111,0b111111111,0b111111111,0b111111111,0b100100101, 0b1001001,0b100100011,0b101110111,0b101110110,0b101101100,0b110110110,0b101101110,0b100100110,0b11011110,0b100100111,0b101110111,0b100100101,0b100100101,0b100011101,0b11011101,0b10010110,0b10010111,0b11001111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b10001111,0b11010111,0b11010111,0b10010111,0b10010111,0b100100111,0b100011111,0b100011110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b100100111,0b10010111,0b10001111,0b11010111,0b10010111,0b11011111,0b111110111,0b111111111,0b101100100,0b10001100,0b10010110,0b10010110,0b11011101,0b11010101,0b110101111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b101101111,0b10010110,0b10010110,0b101101111,0b11010110,0b11011110,0b10001001, 0b1001001, 0b1001010,0b101110111,0b100101111, 0b1010100, 0b1010101,0b101101111,    0b1100,0b11011110,0b10011110,0b100101110,0b110111111,0b110111111,0b111111111,0b111111111,0b111110111,0b111110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b11010011, 0b1000010,0b10001011,0b10001011,0b10001011,0b10001011,0b10001011,0b11001100,0b10001100,0b11001011,0b101011101,0b11010011,0b101101110,0b111111111,0b111111111,0b110111111,0b100110111,0b100110111,0b110111111,0b111111111,0b100100101, 0b1001011,0b100100101,0b101101101,0b101110111,0b110110110,0b111111111,0b111111111,0b110110111,0b100100110,0b10001100,0b11010101,0b11010101,0b10010101,0b10011101,0b100100101,0b100100101,0b100100110,0b100100110,0b100100110,0b100100110,0b11011110,0b10010110,0b11010111,0b10010111,0b10001111,0b10010111,0b10010111,0b10010111,0b11010111,0b11010111,0b11010111,0b10001111,0b10001111,0b10010111,0b10001111,0b10001111,0b11010111,0b11010111,0b11010111,0b10001111,0b11010111,0b11010110,0b110101111,0b11010110,0b110101111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b110101111,0b10010110,0b10010111,0b10010111,0b11010111,0b11010111,0b10010111,0b101101111,0b111111111,0b110101100,0b100011101, 0b1001101,0b10010110,0b11100111,0b11100101,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b11011111,0b10001111,0b11011111,0b100100111,0b11011101, 0b1000011,0b10010010,0b10011011,0b11101110,0b100110111,0b11100110,    0b1011, 0b1001100,0b10010101,0b11011111,0b11011111,0b100100111,0b101101111,0b110110111,0b110110110,0b111110110,0b111110110,0b111110110,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b11011100,0b10000010,0b10001011,0b10001100,0b10001100,0b11001100,0b10001100,0b11001100,0b10001100,0b10001100,0b10001100,0b11001011,0b101011100,0b11010011,0b111111111,0b111111111,0b111110111,0b110111111,0b100111111,0b100111111,0b110111111,0b111111111,0b111111111,0b100101110,0b10011011,0b111110110,0b101110111,0b110110111,0b110110111,0b110110111,0b11100110,0b10010100,0b11011101,0b11010101,0b101100111,0b101101111,0b101101111,0b101101110,0b101101110,0b101101101,0b101110110,0b111111111,0b111111111,0b111111111,0b111110111,0b100100111,0b10001110,0b10010111,0b10010111,0b10010111,0b11010111,0b10010111,0b10001111,0b10010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010111,0b10010111,0b100011111,0b11010110,0b100100111,0b110101111,0b101100110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b11010110,0b11001111,0b11010111,0b11010111,0b11010111,0b11010111,0b11010110,0b110110111,0b110110111,0b110110110,0b110101100,0b100011100, 0b1001100, 0b1011111,0b11100101,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b11010110,0b100100111,0b111110111,0b11011101,0b11011100,0b11011100, 0b1010010,0b100101110,0b101101111,0b101110111,0b11011101,0b10001100, 0b1001100, 0b1001100,0b11011110,0b101101111,0b110110111,0b110110111,0b110111111,0b111111111,0b111111111,0b111111110,0b111111111,0b111111111,0b111111111,0b110110111,0b11100110,0b11011110,0b10001011,0b11001100,0b11001100,0b10001100,0b10001100,0b11001100,0b11010101,0b11010110,0b11010110,0b10001100,0b10001100,0b10001011,0b11001011,0b100100100,0b101101101,0b10010010,0b111111111,0b111111111,0b110111111,0b110111111,0b111111111,0b110110111,0b111111111,0b110111111,0b10010011,0b111101101,0b101110111,0b100101111,0b11100101,0b100101111, 0b1010100,0b11011110,0b11010101,0b11010100,0b101101111,0b101101110,0b101101110,0b101101110,0b101101110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b101100111,0b11010101,0b11010110,0b11010111,0b11010111,0b11010111,0b11010111,0b10010110,0b11010110,0b11010110,0b11010110,0b11010111,0b11010110,0b10010110,0b100011111,0b100100111,0b11010110,0b111110111,0b110101110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b110110111,0b10001111,0b10001111,0b11010111,0b10010111,0b10010111,0b11010111,0b11010110,0b111111111,0b100110111,0b101110111,0b110101100,0b111101100,0b11010011, 0b1010110,0b101101110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110101111,0b111110111,0b110101111,0b11011101,0b10011100,0b10100100,0b100110110,0b100101110, 0b1001011, 0b1001011, 0b1001011,0b11011101,0b10001100, 0b1001011,0b11100101,0b110111111,0b111111110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100101101,0b11100101,0b11100110,0b10010101,0b10001100,0b11001100,0b11001011,0b10001100,0b10001100,0b10001100,0b11001101,0b11010110,0b11010110,0b11011110,0b11010101,0b10001100, 0b1001011,0b110101111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b11100101,0b100100110,0b100011100,0b101011011,0b10100110,0b11100111,0b10011101,    0b1011,0b11011110,0b100100111,0b100100110,0b10001011,0b100100101,0b101101110,0b101101101,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111110,0b110111110,0b111111101,0b111111110,0b111111111,0b111111111,0b101100110,0b11010101,0b100011110,0b11011110,0b11011110,0b100100111,0b100100111,0b100100111,0b100100111,0b100011111,0b11011111,0b11010110,0b100100111,0b11010110,0b101100111,0b111111111,0b111111110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b110110111,0b11010111,0b11010111,0b10010111,0b10010111,0b10010111,0b10010110,0b111110111,0b111111111,0b101110111,0b101110111,0b110101101,0b111101100,0b110100100,0b11010011,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b111110111,0b111111111,0b101101110,0b11100101,0b11101110,0b100110110,0b101110111, 0b1001100, 0b1001100, 0b1001011, 0b1001011, 0b1000011,0b100100110,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b101101110,0b11100101,0b11100110,0b11100110,0b11100110,0b10001100,0b10001100,0b11001100,0b11001011,0b10001100,0b10001100,0b10001100,0b10001101,0b10010101,0b10010101,0b11010101,0b11010110,0b11011101, 0b1001011,0b100011101,0b110101111,0b110101111,0b111111111,0b111111111,0b110110110,0b111110111,0b111111111,0b110111111,0b10011101,0b11100110,0b11011101,0b100100101,0b10100110, 0b1010100, 0b1001011,0b10010100,0b100100111,0b101101111,0b10010011,       0b1,0b11011011,0b101101110,0b101101110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110110,0b110111110,0b110111110,0b111111110,0b111111110,0b111111111,0b111111111,0b110110111,0b100100101,0b11011101,0b101101111,0b101101111,0b101101111,0b101101111,0b101101111,0b101100111,0b100011110,0b100011110,0b100011110,0b100100110,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b101100111,0b10001110,0b11011111,0b11011111,0b10001111,0b101101111,0b111111111,0b111111111,0b110111111,0b101110111,0b110101110,0b111101101,0b111101011,0b110100001,0b101101100,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b11100100,0b101110111,0b11101111,0b101110110,0b101110111,0b101110111,0b11011110, 0b1001100,0b101101111,0b101110111,0b110111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b110110110,0b100100101,0b100100110,0b11100110,0b11100111,0b11100111,0b11100110,0b100100110,0b10001011,0b11001100,0b11001100,0b10001100,0b11001100,0b11001100,0b11001100,0b10010100,0b11010101,0b11010101,0b11010110,0b11011101,0b10010101,0b100011110,0b11010101,0b110110111,0b111111111,0b110111111,0b101101110,0b101101110,0b101101110,0b111111111,    0b1011,0b10100111, 0b1010101,0b11100101,0b10011110,0b101101111,0b11010100,0b10010101,0b10011110, 0b1010100, 0b1001001,0b10001001, 0b1000010,0b100100101,0b101101110,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110111111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b110110110,0b100100101,0b101101111,0b110110111,0b101101111,0b11100110,0b100011101,0b100011101,0b100011101,0b110101111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b110101111,0b100100110,0b111111111,0b100100111,0b10010110,0b101101111,0b111111111,0b111111111,0b111111111,0b101101111,0b101101111,0b101101111,0b101101101,0b100011011,0b101011010,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110101111,0b110110111,0b100100101,0b101110101,0b101101110,0b110110110,0b110110110,0b100101101,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100100110,0b11100110,0b11100110,0b100100110,0b11100110,0b11100110,0b100100111,0b100100111,0b100100111,0b11011101, 0b1001011,0b10001100,0b10001100,0b11001100,0b11001100,0b11001101,0b11001101,0b11001101,0b11010101,0b11001110,0b11010101,0b11010101,0b100011110,0b11010101,0b101100111,0b110110111,0b110110111,0b111111111,0b101110111, 0b1010100,0b11100111,0b10011110,0b100011110,0b11010100,0b110100110,0b11101111,0b11101111,0b100101111,0b100100110, 0b1001010,0b100011101,0b100101110,0b10100110, 0b1011110, 0b1001100,0b101100111,0b111110111,0b111111111,0b111111111,0b111111111,0b111110111,0b110111111,0b110110111,0b111111111,0b110111111,0b110111110,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b110110110,0b100011100,0b100011101,0b100011101,0b100011101,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111110111,0b100100110,0b111111111,0b111111111,0b110110111,0b10010101,0b10010101,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b101101111,0b101101111,0b110101110,0b100011100,0b100010010,0b110101101,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b101100110,0b101100101,0b100011011,0b100100100,0b100110110,0b110110110,0b110110110,0b110110110,0b110110110,0b101110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b11100101,0b100100110,0b11100110,0b11100110,0b100100110,0b100100111,0b100100111,0b100100111,0b100100111,0b100100111,0b100101111,0b10010100,0b10001011,0b10001100,0b10001100,0b10001100,0b11010101,0b11001101,0b10001100,0b10010101,0b10001101,0b11010101,0b11010100,0b100100110,0b10010100,0b11100110,0b11011101,0b100100101,0b100100101,0b10001011,0b11010100, 0b1001100,    0b1100,      0b11,0b11011101,0b101100101,0b100101111,0b11100111,0b100101111, 0b1001011,       0b1, 0b1001010,    0b1010,0b10011101,0b11100110,0b11011101,0b11010100,0b110110110,0b111111111,0b111111111,0b111111111,0b110110111,0b110110110,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b110111110,0b111111111,0b110101111,0b101100110,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b101100111,0b100011110,0b111111111,0b111111111,0b110110111,0b100100101,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b101101110,0b101100111,0b110101111,0b100011110,0b100010100,0b11010011,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b101100111,0b100010110,0b100010011,0b101100011,0b101101101,0b101110111,0b110110110,0b110110110,0b110110110,0b101110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100101110,0b11100110,0b11100110,0b11100110,0b100100110,0b11100111,0b100100110,0b100100111,0b100100111,0b100100111,0b100101110,0b100101110,0b100100111,0b101101111,0b100011110, 0b1001011,0b10010100,0b10001101,0b10001100,0b10010101,0b10010101,0b10010101,0b10010101,0b11010101,0b11010100,0b101100110,0b10010100, 0b1010100,0b10011100,0b11011100,0b100100101,0b110101110,0b11010011,0b100011110, 0b1010101, 0b1010101,0b100101110,0b110110110,0b100101111, 0b1010100, 0b1001011,0b10010011, 0b1001001, 0b1010010,0b10010011,0b101101110, 0b1000001, 0b1000001,       0b1,0b100101101,0b101110110,0b111111111,0b111111111,0b110110110,0b110110110,0b111110111,0b111110110,0b110101110,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111110111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b10010111,0b100100111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100100110,0b101100111,0b11011110,0b100010101,0b11010100,0b101101110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100011111,0b11001101,0b100011011,0b111101011,0b111111110,0b101110111,0b110110110,0b110110110,0b101101110,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100100101,0b11100110,0b11100111,0b11100111,0b100100111,0b100100110,0b100100111,0b100101111,0b100101110,0b100101110,0b100101111,0b100101111,0b101110111,0b101110111,0b101101111,0b101101111,0b101101111,0b11011101,0b11010101,0b10010101,0b10001101,0b10001101,0b10001101,0b11010101,0b11010101,0b10001100,0b100100111, 0b1010100,0b100100111,0b100100110,0b111110111,0b110101110,0b110101101,0b100100101,0b111111111,    0b1101,0b10011110,0b11011100,0b111110101,0b10010011,    0b1001,    0b1001,0b11010011,0b10010010,0b11010010, 0b1001001, 0b1001001,0b10001001,0b11010011,0b10001001, 0b1001001,0b110101110,0b110101110,0b111110111,0b110110110,0b111110111,0b111110110,0b110101110,0b111110111,0b111111111,0b111111111,0b111111111,0b111110111,0b110110110,0b110110110,0b111111111,0b111111111,0b111110110,0b110110110,0b110110110,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b10010111,0b100100111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b11011101,0b11011101,0b100010101,0b100010101,0b11010100,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b10010100,0b100010011,0b110101011,0b111110110,0b101110111,0b101110110,0b110110110,0b101110110,0b111111111,0b111111111,0b111111111,0b111111111,0b101100101, 0b1001011,0b100100110,0b11100111,0b11100110,0b11100110,0b100100110,0b100101111,0b100100111,0b100101110,0b101110111,0b110111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110111111,0b100101111,0b100101111,0b101110111,0b11011110,0b11011110,0b10001101,0b11001101,0b11010101,0b10010101,0b11010101,0b11010100,0b101100111,0b10010101,0b11010101,0b101100110,0b110100101,0b110101101,0b101101101,0b100100101,0b101110111, 0b1001100,0b11011101,0b10010010,0b10000000, 0b1000000,0b10010010, 0b1010010,0b11011100,0b10001001,0b100011011,0b101101101, 0b1001001, 0b1001001,0b100011011,0b11010010, 0b1000001,0b100011100,0b111101111,0b110101110,0b110110110,0b111110111,0b110101110,0b111111111,0b111111111,0b110110111,0b101101110,0b101101110,0b101101110,0b110110111,0b110110111,0b110110111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b11011110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b100011101,0b100011110,0b100010101,0b11010100,0b100100101,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110101110,0b10001010,0b101011011,0b101100011,0b110101101,0b101110111,0b101110111,0b101110110,0b111111111,0b110111111,0b110110110,0b111111111,0b100010100, 0b1000010,0b10010100,0b100100111,0b11100110,0b100100110,0b100101110,0b100101110,0b100101110,0b101101111,0b110111111,0b110111111,0b111111111,0b111111111,0b110110111,0b110111111,0b110111111,0b110111111,0b100101110,0b101101111,0b101101111,0b101101111,0b11010101,0b11010101,0b11010101,0b11010100,0b10010100,0b11010100,0b11010100,0b100100110,0b11011110,0b11010101,0b101100101,0b111101110,0b110110110,0b110110110,0b100100101,0b11011101, 0b1001011, 0b1000010, 0b1000001,0b10001001, 0b1001001,0b10011011,0b100101110,    0b1001,       0b1,0b101101101,0b100100100,0b11100100,       0b1,0b10010011,0b10010011, 0b1001010, 0b1001010,0b10010011,0b11100101,0b11100100,0b11100100,0b11100100,0b11100101,0b11100100,0b11100101,0b11100101,0b11100101,0b11100101,0b11100101,0b100100101,0b100100101,0b100100101,0b100100101,0b100100101,0b100100101,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b100011101,0b100011110,0b11010101,0b11010101,0b101100101,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110101101,0b11010010,0b100001001,0b110100100,0b110110111,0b101110111,0b100101110,0b110111111,0b111111111,0b110110110,0b111111111,0b10001011,0b10000010,0b10000011,0b11011101,0b100100111,0b100101110,0b100101110,0b100101111,0b101101111,0b110110111,0b110110111,0b101110111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,0b100100110,0b110110111,0b110110111,0b101101111,0b11011101,0b100011101,0b11010100,0b10010100,0b10010100,0b10010011,0b10010011,0b11011100,0b11011101,0b11011101,0b100011100,0b100011100,0b11011100,0b10010011,0b10010011,      0b10, 0b1001010, 0b1001010, 0b1001010,0b11011110,0b11100101,0b10011101, 0b1010100,0b100101111,0b11101110,0b11101101,0b100101110,0b100110110,0b101110111,0b100110111,0b100110111,0b100111111,0b100111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b100011101,0b100011110,0b11010101,0b11010101,0b100010101,0b100011101,0b101100110,0b101101110,0b101101110,0b11010010,0b11001001,0b101100011,0b111110110,0b101101110,0b101110110,0b110111111,0b111111111,0b111110111,0b111110111,0b10000010,0b11001011,0b11000011,0b10000011,0b100100110,0b100101111,0b100101110,0b100101110,0b101110111,0b111111111,0b110111111,0b101110111,0b110111111,0b110111111,0b111111111,0b111111111,0b101110111,0b101110111,0b101110111,0b110110111, 0b1001010,       0b1,       0b1,       0b1,       0b1,       0b1,      0b10,      0b10,      0b10,      0b10, 0b1000010, 0b1000010, 0b1000001, 0b1001001,       0b1,       0b1, 0b1000001, 0b1000001, 0b1000001, 0b1001001, 0b1001001, 0b1000001,0b11011101,0b10011111,0b10100110,0b100101111,0b101110111,0b11101111,0b101111111,0b101111111,0b101111111,0b100110111,0b11101110,0b11110111,0b100111111,0b100111111,0b101111111,0b101111111,0b101111111,0b100111111,0b100111111,0b100111111,0b100111111,0b100111111,0b101111111,0b101111111,0b101111111,0b100110110,0b100110110,0b100111111,0b100111111,0b100111111,0b100111111,0b101111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100100110,0b11011101,0b11010101,0b100010101,0b100010101,0b11010101,0b11010101,0b11010100,0b100010010,0b101011011,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110101110,0b10000010,0b10000011,0b11001011,0b11001011,0b10000011,0b101100111,0b100101111,0b100101110,0b101110111,0b111111111,0b110111111,0b110110111,0b110111111,0b111111111,0b110111111,0b110111111,0b110111111,0b100101110,0b101110111,0b101110111,0b110110111,0b10010011,0b10010010,0b100100101,0b11100100,0b11011100,0b10010100,0b10010100,0b10010100,0b10001100, 0b1001100, 0b1001100,0b10001011,0b10001010,       0b0, 0b1001001,0b100011100,0b11010011,0b11010010,0b10010010,    0b1001,       0b1,0b10010100,0b11011110,0b10010111,0b11100111,0b10010110,0b10011110,0b11100111,0b10011101,0b100101111,0b100101111,0b10100101,0b11110111,0b100111111,0b11110111,0b100101111,0b101110111,0b10011110,0b10100101,0b100110110,0b100111111,0b100111111,0b100111111,0b100111111,0b101111111,0b101111111,0b110111111,0b10011100,0b100110111,0b100111111,0b100111111,0b100111111,0b101111111,0b101110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b100100110,0b11010101,0b11010101,0b100010101,0b11010101,0b11010101,0b11010100,0b101011011,0b111111110,0b111111111,0b110110111,0b110111111,0b111111110,0b111111111,0b101100101,0b10000010,0b10000011,0b11001100,0b11001011,0b11000011,0b10000011,0b101101111,0b100101111,0b110110111,0b110110111,0b110110111,0b110111111,0b110111111,0b111111111,0b110111111,0b110111111,0b101110111,0b110111111,0b100101110,0b101110111,0b101110111,0b110110111,0b10010011,       0b1,    0b1010, 0b1010011,0b10010100,0b11010100,0b100011101,0b100100110,0b100011101,0b11010101,0b11010101,0b11010100,0b100011100, 0b1001001,0b111111111,0b111110111,0b100011011,0b100011010,0b110101101,0b10010011, 0b1001011,0b10010100,0b10001101,0b10001110,0b10010101,0b10010101,0b10010110,0b10011110,0b10010101,0b11011110,0b11011110,0b10011110,0b11101111,0b11101111,0b11011110,0b11011110,0b100011111,0b10010101,0b11011101,0b110110111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b110111111,0b110111111,0b110111111,0b101111111,0b101111111,0b101111111,0b101111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b100100101,0b11010100,0b11010101,0b11010101,0b100010100,0b101100011,0b111101100,0b110110110,0b101101110,0b101110110,0b111111111,0b100011101,0b10000010,0b11001011,0b11001011,0b10000011,0b11000011,0b11001011,0b10000011,0b101101111,0b101110111,0b110110111,0b111111111,0b111111111,0b110111111,0b110110111,0b110110111,0b110110111,0b101110111,0b101110111,0b101110111, 0b1001011,0b110110111,0b101110111,0b101110111,0b11011101,0b10001100,0b11100110,0b10010100,      0b10,      0b10,      0b10,      0b10, 0b1001010, 0b1000011,0b10001100,0b10001011,0b11011011,0b111111111,0b111111111,0b110101110,0b100011010,0b101100011,0b11010011,0b11011101, 0b1001100, 0b1001100, 0b1001100, 0b1001100,0b10001100,0b10001101,0b10001101,0b10010101, 0b1001100,0b11011101,0b10001100,0b10010100, 0b1001100,0b10010101,0b10010101,0b11010101,0b11011110,0b11011101,0b11100110,0b100100110,0b100101110,0b11100110,0b11100111,0b100100110,0b110110111,0b111111111,0b101101110,0b100101111,0b100101110,0b100101110,0b101101110,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111110111,0b110101111,0b101100110,0b110101110,0b100011011,0b110101100,0b111110110,0b110101111,0b111111111,0b100100100,0b10000011,0b11000011,0b11001011,0b11000011,0b10001011,0b11001011,0b11001011,0b10000011,0b110110111,0b110111111,0b110111111,0b110110111,0b110110111,0b101110111,0b101110111,0b110110111,0b101110111,0b101110111,0b101110111,      0b10,       0b1,0b101110111,0b101110111,0b101110111,0b10010100, 0b1000010,0b101101111,0b101101111,0b10010100,0b11010100,0b11010100,0b10001011,0b10010010,0b100011100, 0b1000001,0b10010011,0b111111111,0b111111111,0b110110110, 0b1001001,0b11011011,0b10010010,0b10001011, 0b1001101,0b11011110,0b10010101, 0b1001100, 0b1001101,0b10011101, 0b1010100, 0b1001100, 0b1010101,0b10010101,0b11011110,0b11011101, 0b1001100,0b10001100,0b10001100,0b10001100,0b10010100, 0b1010100, 0b1010011, 0b1010100, 0b1001100,0b10010100, 0b1001100,      0b11,      0b10,0b110110111,0b101101110,0b10010100,0b10011101,0b10011101,0b11011100,0b110110110,0b110110111,0b110110111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b100100101,0b111110111,0b110110110,0b111110110,0b110110110,0b111111111,0b100011101,0b10000011,0b11001011,0b11000011,0b11001100,0b11001011,0b11001011,0b11001011,0b10000011,0b10010011,0b111111111,0b110111111,0b110111111,0b101110111,0b101110111,0b101110111,0b11100110,0b101110111,0b101110111,0b101110111,0b101110111, 0b1001011,       0b1,0b100100101,0b101110111,0b101110111,0b11010101,       0b1, 0b1000001,0b10010011,0b10010011,0b11010100,0b11010100,0b101100110,0b111111111,0b110110111,0b100011101,0b111111111,0b111111111,0b101110110,       0b1, 0b1000001,       0b1, 0b1010011,0b11011110,0b10011110,0b11100111,0b101110111,0b100101111,0b100110111,0b10011110,0b10011101, 0b1011101,0b10100110,0b10011101,0b10011101,0b10011101, 0b1001100, 0b1001100,0b10001101, 0b1001100,0b10010100,0b11011101,0b11011101,0b11011101, 0b1001100, 0b1001011,0b11011101,0b10011101, 0b1001011,0b110110111,0b11011100,0b10010100,0b11011110,0b10011101,0b100100101,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b101101110,0b100011101,0b100100101,0b111110111,0b110110111,0b110110110,0b111111111,0b101100101,0b10000010,0b11000100,0b11001011,0b11001011,0b10001100,0b10001011,0b11001011,0b10001011, 0b1001010,0b111111111,0b111111111,0b110111111,0b101110111,0b101110111,0b101110111,0b101110111,0b11100110,0b100101110,0b101110111,0b101110111,0b110110111,0b10010100,0b10001011,0b10010011,0b101110111,0b100101111,0b11011101,0b11010011, 0b1001001, 0b1000001, 0b1000010, 0b1000010,0b100100110,0b111110111,0b111111111,0b100011101,0b101101111,0b101101111,0b100100101,0b10001010, 0b1001001, 0b1001001,0b10010011,0b11100110,0b11100111,0b11011111,0b10010110,0b10011110,0b10100110,0b10100110,0b100101111,0b11100111,0b11101111,0b11101111,0b100101111,0b10100110,0b101111111,0b100110111, 0b1010100,0b100101111,0b100100111,0b10011101,0b10010100,0b10010100,0b10011101,0b11011101,0b11011101,0b11011110,0b10010100,0b100100101,0b101110111,0b11011100,0b11011101,0b11011101,0b11011101,0b100101110,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b110111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b100011110,0b100011101,0b100011101,0b101101110,0b110110110,0b110110110,0b111111111,0b101101110, 0b1000010,0b11001011,0b11001100,0b11001011,0b10001100,0b10001100,0b10001100,0b10001011, 0b1000010,0b110110111,0b110111111,0b110111111,0b111111111,0b100101110,0b110110111,0b101110111,0b101110111,0b101101110, 0b1010011,0b101110111,0b101110111,0b101110111,0b11011101,0b11001100, 0b1000011,0b101101110,0b101110111, 0b1001011,0b11010100,0b11010100,0b10001011,      0b10,0b11011100,0b100100101,0b101101101,0b101101110,0b11011101,0b11010101,0b100100110, 0b1000001,0b10001001, 0b1001001,       0b1,0b11100110,0b11100110,0b11011111,0b11011111,0b10011110,0b10011110,0b10011110,0b10100110,0b10011110,0b11100111,0b11110111,0b11100111,0b100101111,0b100101111,0b100111111,0b100111111,0b11100110,0b11100111,0b11011110,0b100101111,0b11101111,0b101110111,0b100110111, 0b1011100,0b10100111,    0b1011,0b11011101,0b110111111,0b100110110,0b11101110,0b11101110,0b100101110,0b101110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111110111,0b110110111,0b110110111,0b111111111,0b110110111,0b111111111,0b110110111,0b110110111,0b111111111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,
0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111110111,0b111111111,0b111111111,0b110111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110111111,0b101110111,0b11011101,0b100011101,0b100011110,0b101100110,0b110110110,0b110110110,0b110111110,0b111110111, 0b1000010,0b11001011,0b11001011,0b11001011,0b10001100,0b10001011,0b10001100,0b10001100,0b10000011,0b100011101,0b111111111,0b110111111,0b110111111,0b100101110,    0b1001,0b11011100,0b110110111,0b101110111,0b110110111,    0b1001,0b100110111,0b100110111,0b101110111,0b100011101,0b11001100,0b11001101,0b10010100,0b100101110,      0b10,0b10001100,0b11001101,0b11001101,0b11010100,0b11011011,    0b1001,0b10010010,       0b1, 0b1001011,0b10010100,0b101100110, 0b1000000,0b10001000,0b10001010,0b11011100,0b10011101,    0b1100, 0b1001100,0b10001101,0b10001110,0b11011111,0b100101111,0b11100110,0b11011111,0b11100111,0b11101111,0b11100111,0b10011101,0b10100101,0b100111111,0b100111111,0b100110111, 0b1010101, 0b1010101,0b11101111,   0b11101,0b100111111,0b100111111,0b100111111,0b11101111,0b10011101,0b101101111,0b101110111,0b101111111,0b100111111,0b100111111,0b110111111,0b110110111,0b110110111,0b110110111,0b111111111,0b111110111,0b111110111,0b111110111,0b110110111,0b110110111,0b111110111,0b111110111,0b110110111,0b111111111,0b110110111,0b110110111,0b110110111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111111111,
0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b110110111,0b110110111,0b110111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110111111,0b111110111,0b101101111,0b100011110,0b100011101,0b100011101,0b100011101,0b101101110,0b110110110,0b110110110,0b111111111,0b10000010,0b11001011,0b11001011,0b10001011,0b10001100,0b10001100,0b11001100,0b11001100,0b10001011, 0b1001011,0b110110111,0b110110111,0b110110111,0b101101110, 0b1000010, 0b1000010, 0b1001010,0b101101111,0b101110111,0b101110111,0b10011100,0b11011101,0b101110111,0b101101111,0b11011101,0b10001011,0b11001100,0b11001100, 0b1000010,    0b1001,    0b1001,0b10001011,0b11001100,0b11001101,0b11001100,0b11010100, 0b1000011,       0b1, 0b1001001, 0b1001000,0b10001010,      0b10,0b11011101,0b100110111,0b10100101, 0b1010101, 0b1001100,0b10000101, 0b1001100, 0b1001100, 0b1001100,0b10010101,0b10010101,0b100100111,0b10011110,0b10011110,0b11100111,0b10011111,0b10010110,0b100101111,0b101110111,0b100101111,   0b10100,0b10011110,0b100101111,0b101111111,0b100110111,0b101111111,0b100111111,0b11111111,0b101111111,0b110110110,0b110111111,0b100110111,0b11101111,0b101101110,0b111111111,0b111110111,0b110110111,0b110110111,0b111111111,0b110110110,0b110111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b111110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b110110111,0b101101111,0b101101111,0b100100110,0b100011110,0b100011101,0b101100110,0b101101110,0b110110110,0b111111111,0b11001011,0b10000011,0b11001011,0b11001011,0b10001100,0b10001100,0b10001100,0b10001100,0b11001100,0b10001100, 0b1001011,0b110110111,0b101110111,0b110110111,       0b1,0b10001011, 0b1000010,0b10010100, 0b1001010,0b110110111,0b101110111,0b100101110, 0b1000010,0b101101111,0b101101111,0b11011101, 0b1000010,0b11010100,0b11001100,0b11010100, 0b1001010, 0b1000001, 0b1000001,0b10001011,0b11001100,0b11001101,0b11001101,0b11010101,0b10010011, 0b1001010,       0b1, 0b1001011,0b11011101,0b11100110,0b11100110,0b101110111,0b11100110, 0b1001100,0b10010101, 0b1001100, 0b1001100,0b10001100, 0b1001100, 0b1010101, 0b1001100, 0b1001100, 0b1010100,0b10011110,0b10011110,0b11011110,0b11100110, 0b1011100,0b101111111,0b101111111, 0b1011101,0b10011110,   0b10100,0b10100110,   0b10011,0b101111111,0b100111111,0b101111111,0b111111111,0b101101111,0b10011110, 0b1011101,0b110111111,0b111111111,0b111110111,0b110110111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111110111,0b111110111,0b111110111,0b110110111,0b110111111,0b111111111,0b110110111,0b101101111,0b101101111,0b101101111,0b11011110,0b100011110,0b100011110,0b101101111,0b101101101,0b110110110,0b110101110,0b10000011,0b11000011,0b11000100,0b11001100,0b10001100,0b10001100,0b10001100,0b10001100,0b10001100,0b11010101,0b10010101,0b101101111,0b101110111,0b101110111, 0b1010010, 0b1000001,0b10001011,0b10001011,       0b1,0b100100101,0b101101111,0b100101110,0b10001011,0b10010100,0b110110111,0b10010100,       0b1,0b10001011,0b11001100,0b11001100,0b11010101, 0b1000010, 0b1001001,       0b1,0b10001011,0b11010101,0b11001100,0b11001101,0b11010100,0b11010101, 0b1000100, 0b1001100,0b11100111, 0b1011101, 0b1010101,0b100110111,0b100101111,0b11101111, 0b1010101, 0b1001100, 0b1001011, 0b1001100, 0b1001100, 0b1001100, 0b1001100, 0b1010100, 0b1010100,0b10010101, 0b1001100,0b10011101,0b10011101,0b100110111,0b100111111,0b101111111,0b100110111,   0b10100, 0b1011101,0b11100111, 0b1010101,0b10011110,0b11100110,0b101110111,0b111111111,0b101101111,0b10011101,0b100101111,0b110111111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b110110111,0b110110111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111110111,0b111110111,0b111111111,0b111111111,0b110111111,0b110110111,0b101101111,0b101101111,0b101101111,0b101101111,0b11011110,0b11011101,0b101100110,0b101101110,0b100101101,0b111111111,0b10001010,0b11001011,0b11001100,0b11001100,0b11001100,0b10001100,0b10001100,0b11001100,0b10001101,0b10010101,0b11010110,0b11011101,0b100100111,0b101110111,0b101110111, 0b1001010, 0b1000001,0b11010100, 0b1000010, 0b1000010,0b10001011,0b100100101,0b101110111,0b10000010,0b10001100,0b10001100, 0b1001010, 0b1001010, 0b1001010,0b11001100,0b11001101,0b11001100,0b10010100, 0b1001010, 0b1001001, 0b1000001, 0b1001011,0b11010100,0b11001100,0b11001101,0b10000100, 0b1001100,    0b1100, 0b1001100,0b100100111,0b11100110,0b11101111,0b11101111,0b11101111,0b11100111,0b100100111,0b100100111,0b10010101, 0b1001100,0b10010101,0b10001101,0b10010101,0b10010101,0b10001100,0b10001101, 0b1001100, 0b1001100,0b10011101,0b10100101,0b11101110,0b11101111,0b11100111,0b11100111, 0b1010101,0b10011110,0b10011111,0b11011101,0b111111111,0b111111111,0b101100110,0b100100110,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b110110111,0b101101111,0b101101111,0b101101111,0b101101111,0b100100111,0b11011110,0b100011101,0b101101110,0b101101101,0b101101110,0b110101110,0b10000010,0b11001011,0b11001011,0b11001100,0b11001100,0b10001100,0b10001100,0b11001100,0b10010101,0b11010110,0b11011110,0b10010100,0b11100101,0b101110111,0b101110111,      0b10,0b10001010,0b11010011, 0b1000001,0b10001011,0b11010100,0b10001011,       0b1,0b10001011,0b11001100,0b10001100,0b10001100, 0b1000010, 0b1000001,0b11001011,0b11001100,0b11001101,0b10001100,0b10010100, 0b1000010,    0b1001,    0b1001, 0b1001010,0b10001100, 0b1000100,0b10001100,0b10010101, 0b1001100, 0b1001100,0b10010101,0b10011110,0b11101111,0b11110111,0b11101111,0b10010110,0b10010110,0b11011111,0b11100111,0b10011110, 0b1001100, 0b1000100,0b10001101,0b10010101, 0b1001100, 0b1001101, 0b1001101, 0b1001100,0b10010101,0b11011101,0b10011101, 0b1010100, 0b1001100, 0b1010100,0b10010101,0b10010110,0b10010110,0b101101110,0b111111111,0b111110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b110110111,0b101101111,0b100100111,0b11011110,0b11100110,0b101101111,0b100100111,0b11011101,0b100100110,0b100101101,0b101101101,0b111110111,0b11010100,0b10001011,0b10001011,0b11001011,0b11001100,0b11001100,0b11001100,0b10001100,0b11001100,0b11010101,0b11011110,0b11011101,       0b1,0b10010011,0b101110111,0b101110111,      0b10,0b11010100,0b10010010,       0b1,0b10001011,0b11001100,0b10001100,      0b10, 0b1001011,0b11001100,0b11001101,0b10010100,      0b10, 0b1001010,0b10001011,0b11001100,0b11001100,0b11001101,0b10001100,0b11010100,      0b10,       0b1, 0b1010011,0b101110111, 0b1010100,0b10010101, 0b1001100, 0b1001011,0b10010100, 0b1000011, 0b1001100,0b10100110,0b100110111,0b11101111,0b10011111,0b10010110,0b10010110,0b10011110,0b11100110,0b10011110,0b10010101, 0b1001100, 0b1001100, 0b1001100, 0b1001100, 0b1001100,0b10001101, 0b1001100,0b10010101, 0b1001100, 0b1001100,0b10010101,0b10010101, 0b1001100, 0b1001100,0b11011101,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b110111111,0b111110111,0b110110110,0b111111111,0b111110111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110110111,0b110110111,0b110111111,0b110110111,0b101110111,0b101101111,0b100100111,0b100011110,0b100011110,0b11011110,0b101100111,0b101100110,0b100011101,0b101101110,0b101101110,0b100101101,0b111110111,0b10000011,0b11001100,0b10001100,0b11001100,0b10001011,0b11001100,0b11001100,0b11001100,0b10001101,0b11011101,0b11011101, 0b1000010, 0b1000010,0b10010011,0b101110111,0b101101111, 0b1000011,0b11010100, 0b1001010,       0b1,0b10010100,0b11001101,0b11001100, 0b1001010, 0b1000011,0b11001101,0b11001101,0b11001100, 0b1001010,    0b1001,      0b10,0b10001100,0b11001100,0b11001100,0b11001100,0b10001100,0b10001100,0b10010101,0b11100110,0b11101111,0b11101111,0b11100110, 0b1000011,0b10001011, 0b1001011, 0b1001100, 0b1001100,0b10010100,0b11100110,0b10100110,0b11101111, 0b1011110,0b10011110,0b10011101,0b10011110, 0b1011110,0b10011110,0b10011110, 0b1010101, 0b1001100, 0b1010100,0b10010100,0b10001100,0b10001101, 0b1001101, 0b1001100,0b10010101,0b100100111, 0b1001100, 0b1001100,0b11011101,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b110110111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b101101111,0b100100110,0b100011110,0b100011110,0b100011101,0b11011101,0b101100110,0b101100110,0b101101110,0b101101110,0b101101110,0b101101101,0b101101110,0b10001011,0b11001100,0b11001100,0b10001100,0b10001100,0b10001100,0b11001100,0b11001100,0b10001110,0b100011101, 0b1001010,       0b1,0b10001100,0b10001100,0b101101111,0b11011101,0b10001100,0b11010100, 0b1000010, 0b1001010,0b10010100,0b11001101,0b11001100, 0b1000010, 0b1000011,0b10001100,0b11001100,0b11001100,0b10001011,       0b1,    0b1001, 0b1001010,0b11010100,0b11001100,0b10001100,0b10001100, 0b1000100,0b10001101,0b11011111,0b11101111,0b11100111,0b10011110, 0b1001100, 0b1000100, 0b1001100, 0b1001011, 0b1001100, 0b1001100,0b11011110,    0b1100,0b10100110,0b100110111,0b100101111,0b100101111,0b100101111,0b11101111,0b100101111,0b11100111,0b11100111,0b11100111,0b11100110, 0b1001100, 0b1001100, 0b1001101, 0b1001100, 0b1001100, 0b1010100, 0b1001100, 0b1001100,0b11011101,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110110,0b111111111,0b111111111,0b111110111,0b110110111,0b110110111,0b111111111,0b111111111,0b110110111,0b111111111,0b110110111,0b111111111,0b111111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110110111,0b110110111,0b111110111,0b110110111,0b101101111,0b100100110,0b100011101,0b101100110,0b101101110,0b101110110,0b101110110,0b101101110,0b110110110,0b110101110,0b101101110,0b101101110,0b110101110,0b100011101,0b10001011,0b11001100,0b10001100,0b10001100,0b10001100,0b11001100,0b11001100,0b11001100,0b11010101, 0b1001011,       0b1,0b10001011,0b11010101,0b10001011, 0b1001011,0b10001011,0b10010100,0b10001100, 0b1000010, 0b1001010,0b10010100,0b11001101,0b10001100, 0b1000010, 0b1000010,0b11010100,0b11001100,0b11001100,0b11001100, 0b1000010,    0b1001, 0b1001001,0b11010011,0b10001100,0b10001100, 0b1001100, 0b1000011,0b10010101,0b101101111,0b10011110, 0b1001101,0b10001101,0b10010110, 0b1001100, 0b1001100, 0b1001100, 0b1001100, 0b1001100,0b11010101, 0b1000100, 0b1001100,0b100101111,0b11101111,0b100101111,0b11100111,0b10010101,0b10010110,0b10010110,0b11011111,0b10010110,0b10011110,0b11011110,0b10010110, 0b1001101, 0b1001100, 0b1001100, 0b1001100, 0b1001011,0b100100101,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b110110111,0b110111111,0b110110111,0b110111111,0b110110111,0b110110111,0b110111111,0b101110110,
0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110111111,0b110110111,0b101101110,0b101101110,0b101101110,0b110110111,0b110110111,0b110110110,0b100101110,0b100101110,0b101110110,0b110110110,0b110110110,0b110101110,0b110101110,0b110110111,0b10001011,0b10001100,0b10001100,0b10001100,0b10001100,0b11001100,0b10001100,0b11001100,0b11001101, 0b1001011,      0b10, 0b1000010,0b11010101,0b11010100, 0b1000010,      0b10,0b10010100,0b11010100, 0b1001011, 0b1000010,0b10001011,0b10001100,0b11001100,0b10001100, 0b1000010, 0b1000010,0b11010100,0b11001100,0b11001100,0b10001100, 0b1001011,      0b10, 0b1001010,0b10001011,      0b11,    0b1011,0b10010101,0b10010100,      0b11,0b11011101, 0b1010100,0b10010101, 0b1010101, 0b1010101,0b10010110, 0b1000100, 0b1000100, 0b1001100, 0b1001100,0b10010101, 0b1001100, 0b1001100,0b10001101,0b10010101,0b11100110,0b11100111,0b11011110,0b10010110,0b10010110,0b10010110,0b10010110,0b11100111,0b10010110,0b10010110,0b11011110,0b10010110, 0b1001101,0b10010101,0b11011101,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b101110110,0b101110111,
0b111111111,0b110111111,0b110111111,0b111111111,0b111111111,0b111111111,0b110101110,0b101101101,0b100101101,0b110110111,0b110110111,0b110110111,0b110110110,0b110101110,0b11011101, 0b1010100, 0b1010100,0b10011101,0b110110110,0b110110110,0b110110110,0b110101110,0b110101111,0b10001011,0b11001100,0b10001100,0b10001100,0b10001100,0b11001100,0b11001100,0b10001100,0b10001100, 0b1001001,      0b10,0b11010110,0b11010101, 0b1001010, 0b1000001,0b10001011,0b11010100,0b10010100, 0b1001010, 0b1000010,0b11010100,0b11001100,0b10001100,0b10010011, 0b1000010, 0b1000010,0b11010100,0b11001100,0b11001100, 0b1001011,0b100100110, 0b1001100, 0b1001100, 0b1001100, 0b1001100,0b10010100, 0b1001100,0b11010101,0b10010100, 0b1001100,0b10010100,0b10011110, 0b1010100,0b10011110, 0b1010101,0b10010101, 0b1000100,0b10010100,0b10010100, 0b1010100,0b10010101, 0b1001100,0b10001100, 0b1001100, 0b1010101,0b10010110,0b11011111,0b11011111,0b11100110,0b11011101,0b110111111,0b11100110,0b10011110,0b10011110,0b10010110,0b10010110,0b11011111,0b100100110,0b11100101,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b110110111,0b110111111,0b110110111,0b110110111,0b110110111,0b101110110,0b101101110,0b110110111,
0b111111111,0b111111111,0b111111111,0b110110110,0b100011011,0b11010010,0b100011011,0b100011011,0b100011011,0b100011100,0b101101101,0b101101110,0b101101110,0b101101110,0b100101111,0b11100110,0b11011111,0b100101111,0b110110111,0b110110110,0b110110110,0b110101110,0b110101110,0b10001011,0b10001100,0b10001100,0b10001100,0b10001100,0b11001100,0b11001100,0b10001011, 0b1000010,       0b0,0b11010101,0b11010101,0b10010100, 0b1000001, 0b1000001,0b11010100,0b11001101,0b10001011, 0b1001010, 0b1000010,0b11001100,0b11001100,0b11010100,0b10010011,      0b10,       0b1,0b10001100,0b11001101,0b10001100, 0b1010100,0b100101111, 0b1010101,0b11011111,0b10010110,0b101101111,      0b10,0b10001100,0b11010101,      0b11,0b10010100,0b10011101,0b11101111,0b100101111,0b100101111, 0b1001101, 0b1010110, 0b1001101,0b10010100,0b10010100, 0b1010100, 0b1010100, 0b1001100, 0b1001100, 0b1001100, 0b1001100, 0b1001101,0b10010110, 0b1010110,0b10011101,0b110110111,0b101110111,0b10011101,0b10011110,0b10011111,0b10011110,0b10011101,0b101101111,0b101110111,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b110111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111110111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b101101110,0b110110111,0b110110111,
0b111111111,0b101101100,0b101011010,0b100010001,0b11010010,0b100011100,0b100011011,0b101011011,0b101011011,0b100011011,0b11011100,0b100101110,0b101110110,0b110110111,0b110110111,0b110110111,0b101101111,0b101110111,0b101110111,0b110110110,0b110110110,0b110101110,0b101100110,0b10001011,0b10001100,0b10001100,0b11001100,0b11001100,0b10001100,0b10001100, 0b1001010,       0b1,0b11010100,0b11010101,0b11010101, 0b1001011,       0b1,0b10001011,0b11010101,0b11010101,0b10001011, 0b1000001,0b10001011,0b11001100,0b11001100,0b10001100, 0b1001011,       0b1,       0b1,0b10010101,0b10001100,0b10001100,0b10010100,0b10011101,0b11011110,      0b11,    0b1100,0b11011110,      0b11,0b10001101, 0b1000011,      0b11,0b10010101,0b10011101,0b10011101,0b100101111,0b10010101, 0b1001101, 0b1001101,0b10010101, 0b1001100, 0b1001100, 0b1001100, 0b1000011,0b10010100, 0b1001011, 0b1001100, 0b1001100, 0b1000100, 0b1001101,0b10010110,0b11011110,0b111111111,0b11011101,0b10010101,0b10010110,0b10010110,0b10010110,0b100100110,0b111111111,0b111111111,0b111111111,0b111110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b101110111,0b101101110,0b110110110,0b110110111,0b110110110,
0b101101110,0b101100011,0b110011011,0b110100011,0b101101100,0b110110110,0b110110110,0b110101100,0b110100100,0b101100100,0b101101101,0b101101110,0b110110111,0b111110110,0b111110110,0b110110110,0b110110110,0b101110110,0b101110110,0b101101110,0b110110111,0b110101110,0b101100101,0b10001100,0b10001100,0b11001100,0b11001100,0b11001100,0b10001100, 0b1001010, 0b1000001, 0b1001010,0b11010110,0b11010101,0b11010100,       0b1,      0b10,0b11010101,0b11001101,0b11010100, 0b1001010, 0b1001010,0b10001011,0b10001100,0b10001100,0b11100110,0b100101111,0b101110111,0b110111111,0b101110111, 0b1001100,0b10001100,0b11011101, 0b1010100,0b10011101,0b11101111,0b100101111,0b11100110,0b11100110, 0b1001100, 0b1000011, 0b1000011,      0b11,    0b1011, 0b1001100, 0b1001101,0b10001101,0b10001101,0b10010101,0b10010101,0b10001101,0b10001100, 0b1000011,0b10001100,0b100100111,0b10010100,0b10001100, 0b1001100, 0b1001100, 0b1001100, 0b1001100,0b100100111,0b11011110,0b10010110,0b10010110,0b10010111,0b10010111,0b11010110,0b110110111,0b111111111,0b111111111,0b111111111,0b111110111,0b110110111,0b110110111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b100101110,0b101110110,0b110110111,0b110110111,0b110110110,
0b111110110,0b101100011,0b111100100,0b110100100,0b111111110,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b110110110,0b110110111,0b110110111,0b111110110,0b111110110,0b111110110,0b110110110,0b110110110,0b110110111,0b110110111,0b110110110,0b110101110,0b101100101,0b10001100,0b11001100,0b10001100,0b11001100,0b10010100, 0b1001010, 0b1001001, 0b1000010,0b11011101,0b11010110,0b11011101, 0b1001010,       0b1,0b10010100,0b11010101,0b11010101,0b10010011,       0b1,       0b1,0b10010100,0b10010101,0b11011110,0b101110111,0b101110111,0b100101111,0b101111111,0b11100110,0b10011101,0b10001100,0b10010101,0b100100111,0b100101111,0b100101111,0b11100110,0b101110111,0b100100111,0b11011110, 0b1000011, 0b1000011, 0b1001011, 0b1001011, 0b1000011, 0b1000100,0b10001101,0b10001101,0b10010101,0b10001101,0b10001101,0b10010101,0b10001100,0b111111111,0b100100110, 0b1001100,0b10010101,0b10001100, 0b1001100, 0b1001100, 0b1001100, 0b1001100,0b10010110,0b10010110,0b10010110,0b10010110,0b10010101,0b101101111,0b111110111,0b111110111,0b111110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b101101110,0b100101110,0b101101110,0b110110110,0b110110110,
0b111111110,0b101100011,0b110100100,0b111110110,0b111111111,0b110111111,0b101110110,0b110111111,0b110111111,0b110110111,0b110101110,0b110110110,0b110110110,0b110110111,0b111110111,0b111110111,0b111110111,0b111110111,0b110110111,0b110111111,0b110110110,0b101101110,0b101100101,0b11001100,0b11001100,0b11001100,0b10001100, 0b1001010, 0b1001001,       0b1,0b11010100,0b11010101,0b11010110,0b11011101,       0b1, 0b1001001,0b100011110,0b11010101,0b10010101,0b11011101,0b11100100,0b100101110, 0b1010100,0b10010101, 0b1010100,0b10100101,0b11100110,0b10100110,0b101110111,0b101110111,0b11011101, 0b1001100, 0b1001011, 0b1001100,0b11011110,    0b1011, 0b1010100,0b11100110, 0b1010100, 0b1001100, 0b1000011, 0b1000011, 0b1000011, 0b1000011,0b10000011, 0b1000100, 0b1001100,0b11011110, 0b1001100,0b10001101, 0b1001110, 0b1001101,0b101101110,0b110110111,0b10010011, 0b1001100,0b10001100,0b10001100, 0b1001100, 0b1000100, 0b1001100, 0b1001011, 0b1001100,0b10010101,0b10010110,0b10010101,0b11100110,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111110111,0b111110111,0b110110111,0b101110110,0b100101101,0b100101110,0b100101101,0b110110110,0b110110111,
0b110111111,0b101101110,0b101110110,0b101110111,0b110111111,0b110111111,0b101110111,0b101110111,0b110111111,0b111111111,0b110110110,0b110101110,0b110101110,0b110110110,0b111110111,0b111110111,0b101110111,0b110110111,0b110110111,0b110110110,0b101110101,0b110110110,0b101100101,0b11001100,0b11001100,0b11010100, 0b1001010, 0b1001001, 0b1000001,0b10001100,0b11010101,0b11010101,0b11100110,       0b1,       0b1,0b10010100,0b10010100, 0b1010100,0b11101111,0b100111111,0b100111111,0b11101110,0b10011101,0b11011110,0b10011101,0b101111111,0b101111111,0b110111111,0b111111111,0b110110111,0b11011101,0b10011101,0b10010101,0b10010100, 0b1000011, 0b1001100,0b10001100, 0b1000100,0b10001101,0b10001101,0b10000100, 0b1000011, 0b1000011, 0b1000100, 0b1000011, 0b1000011,0b10010101,0b10001101,0b11011111,0b11011110, 0b1010101,0b10010101,0b100100111,0b11011110,0b10010100,0b10010100, 0b1001100, 0b1000100, 0b1000100, 0b1001100, 0b1001100, 0b1001100, 0b1001100, 0b1001100,0b10001100,0b100100110,0b111110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b110111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b101101110,0b100101110,0b100101110,0b100101110,0b100101101,0b110110110,0b110110111,0b101110110,
0b101110110,0b101110111,0b101110111,0b101110110,0b110110110,0b101101110,0b100101110,0b101110111,0b110111111,0b111111111,0b111111111,0b111110111,0b110110111,0b101110110,0b101110110,0b110110111,0b111110110,0b101100100,0b101101101,0b110110110,0b101101110,0b110110110,0b101100110,0b10001011,0b10001100, 0b1000011, 0b1001011,       0b1,    0b1010,0b10010100,0b10010101,0b10001100,0b11101110,0b100101111,0b100101111,0b10010100,0b11011101, 0b1010100,0b100111111,0b100111111,0b100111111,0b10011101,0b10010100, 0b1010100,0b11100110,0b100110111,0b101111111,0b111111111,0b110111111,0b111111111,0b100100101,0b101101111, 0b1001011,0b10010100,0b100011110,0b101100111,0b11011101, 0b1001100, 0b1001100, 0b1001100,0b10001100, 0b1000011, 0b1000011, 0b1000011, 0b1001011, 0b1001011, 0b1001011,0b10010101, 0b1001101, 0b1010101, 0b1010101,0b10010101,0b10001101,0b10001101,0b10001100, 0b1000011, 0b1001100, 0b1000100,0b10001100,0b11010101, 0b1001100, 0b1000011,0b10010100, 0b1001011,0b101101111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b101101110,0b101110110,0b100101110,0b101110110,0b110110111,0b110110111,0b110110111,0b101101110,
0b101110111,0b100101111,0b101110111,0b101110110,0b101110110,0b101101110,0b100101110,0b11101110,0b110111111,0b111111111,0b111110110,0b111110111,0b111111111,0b111111111,0b110111111,0b100101101,0b111100011,0b110100011,0b101100101,0b101101110,0b110101111,0b110101110,0b110101110,0b10010011, 0b1001100,0b11010110,0b11011111,0b11011101,0b10010100,0b10011101,0b10011101,0b100100111,0b100111111,0b101111111,0b11100101,0b11011101,0b10010100,0b100101111,0b100111111,0b11110111,0b11100110, 0b1000100,0b10001100, 0b1001100,0b10011101,0b101110111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111, 0b1000010, 0b1000011, 0b1000011,0b100100110,0b110110111,0b100100110,0b11100110, 0b1010100, 0b1010101,0b100100111,0b10010101, 0b1001100,0b10001100, 0b1001100, 0b1000011, 0b1001011, 0b1000011,0b10010101, 0b1001101, 0b1001101,0b10001101,0b10010101,0b10001101,0b10001101,0b10001101, 0b1000011, 0b1001100,0b101101111, 0b1000011, 0b1000011,0b100100110,0b100100110,0b110110111,0b111111111,0b110110111,0b110110111,0b111111111,0b110110111,0b111111111,0b111111111,0b110110111,0b110110111,0b110111111,0b110110111,0b110110111,0b110110111,0b110110111,0b111110111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110111,0b110110111,0b110110111,0b101110110,0b101110110,0b110111111,0b110110111,0b110110111,0b101110110,
0b101110110,0b100101101,0b110110111,0b101101110,0b110110111,0b110110111,0b100101110,0b11101110,0b110111111,0b101100100,0b110100011,0b101100011,0b101101100,0b111111111,0b111111111,0b101100100,0b111100011,0b101100011,0b111110111,0b110110110,0b110110110,0b110101110,0b110110111,0b10010100, 0b1010101,0b10011111,0b10010110,0b10010101,0b11011101,0b10011101,0b11100110,0b11100111,0b10100110,0b100101111, 0b1010100, 0b1001100, 0b1001011,0b10100110,0b10100101,0b11101111,0b11011110,0b10001101,0b10010101,0b10010101,0b100101110,0b110110111,0b111110111,0b111111111,0b101111111,0b110111111,0b11011100, 0b1000010, 0b1000011, 0b1000011,0b11010100,0b10010100, 0b1001011,0b10011101,0b101110111,0b100101111, 0b1010101, 0b1001100,    0b1011, 0b1001011, 0b1001011, 0b1001100, 0b1000011, 0b1001100, 0b1001100,0b10010101,0b10010101,0b10001101,0b10001101,0b10001101,0b10001101,0b10010101,0b10001100,0b110110111, 0b1001011, 0b1000011,0b100100101,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b111110111,0b111111111,0b101101110,0b100101110,0b101110110,0b110110111,0b110110111,0b110110111,0b101101101,
0b110110111,0b110110110,0b110111110,0b110110110,0b101101110,0b110111111,0b110111111,0b101110111,0b101110111,0b101100100,0b110100010,0b110011001,0b100011010,0b101101101,0b110101101,0b101010001,0b100011010,0b110110110,0b111111111,0b110110110,0b110110110,0b111110111,0b100011101, 0b1001100,0b10011110,0b11100111,0b10010101,0b11011110,0b10011101,0b10100101,0b101110111,0b10011110,0b100101111,0b10010101, 0b1001100,0b10010100, 0b1010100,0b100110111,0b100110111,0b10011101,0b10010101,0b10010101,0b11011110,0b11011101,0b100100101,0b110110111,0b110110111,0b101100111,0b100110111,0b110111111, 0b1001011, 0b1000011, 0b1000011, 0b1000011,      0b11, 0b1001011, 0b1001100, 0b1001100, 0b1001100,0b100100111,0b100101111,0b11100110, 0b1010100,0b10010100, 0b1001011,0b10010100,0b10010100,0b10010101, 0b1001011, 0b1001100,0b10001101,0b10001101,0b10001101,0b10001101,0b10010110,0b10010101,0b110110111,0b11010100,0b11010100,0b110110111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b111110110,0b111111111,0b110110111,0b101101110,0b100101101,0b101110110,0b110110111,0b110110111,0b110110111,0b101101110,
0b110110111,0b110110111,0b110110111,0b110111111,0b110110110,0b101101101,0b101110110,0b101110110,0b110111111,0b110110110,0b111101101,0b101011011,0b101100110,0b110101110,0b100010010,0b101010001,0b100100100,0b111111111,0b110110111,0b110110110,0b110110111,0b101101110, 0b1000011,0b10011110,0b11011110,0b11100110,0b10010101,0b10010100, 0b1010100,0b11101111,0b100101111,0b10011110,0b11011110,0b10010101,0b10001100,0b10010101,0b11100110,0b101111111,0b11100110,0b100101111,0b10010101,0b10010101,0b11011110, 0b1001011,0b11100101,0b100101111,0b11100110,0b11011110,0b10011110,0b11011110, 0b1001100, 0b1000011, 0b1000011,      0b10, 0b1001011,0b11011101,0b100100110, 0b1001100,0b10010101, 0b1001100, 0b1001100,0b10011101,0b10011101, 0b1001011, 0b1001011,0b10010100, 0b1001100, 0b1001011, 0b1000011, 0b1000011,0b10001100,0b10001101,0b10010101, 0b1001101, 0b1001100,0b100101110,0b101101110,0b110110111,0b111111111,0b110110111,0b110111110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110110,0b110110110,0b111110110,0b111110110,0b111110111,0b110110111,0b110110111,0b101110110,0b101110110,0b110110110,0b110110111,0b110110111,0b110110110,
0b11011101,0b101101111,0b110110111,0b110110111,0b110111111,0b111111111,0b111111111,0b111110110,0b111111110,0b111111111,0b110110111,0b11011110,0b10010101,0b11011101,0b101011100,0b100010001,0b101100011,0b101101100,0b110110110,0b110110111,0b110101111, 0b1000011,0b11011110,0b10011110,0b11100111, 0b1001100,0b10010100, 0b1010011,0b10011101,0b10100110, 0b1011101,0b11100110,0b10010101, 0b1001100,0b10001100,0b10010100,0b11101110,0b100110111,0b101111111,0b100101111,0b11011110,0b10010101, 0b1001100, 0b1001011,0b10100101,0b100111111,0b100111111,0b101111111, 0b1010101,0b11011110, 0b1000011, 0b1000011, 0b1000011,0b10010100, 0b1001011,0b10010101,0b11011110, 0b1001100,0b10010101,0b10011110,0b10011101,0b11100111,0b11100110,0b10010101, 0b1001100,0b10010011, 0b1001010, 0b1001011, 0b1000100, 0b1000011,0b10010100,0b101100110,0b10010101,0b10010101,0b11100101,0b111111111,0b111111111,0b111111111,0b110110111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111110111,0b111111111,0b111111111,0b111110111,0b110110111,0b110110111,0b111110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110110,0b110110110,0b110110111,0b110110111,0b110110110,0b110110111,0b110110110,0b110110111,0b110110111,0b110110110,0b110110110,0b110110111,0b110110111,0b110110111,
0b10001100, 0b1001011,0b100100110,0b110110111,0b111111110,0b111110111,0b111110111,0b111111111,0b111111111,0b110110111,0b100101111, 0b1010110,0b10011110,0b101101111,0b110110110,0b110110110,0b110101100,0b110101101,0b110110111,0b110101111, 0b1000011,0b11010101,0b100100111,0b11100110, 0b1010100,0b11011101,0b11011101,0b100100110,0b101110111,0b10100110,0b100101111,0b101110111, 0b1010100, 0b1001100,0b10011101,0b11100110,0b101111111,0b101111111,0b100101111,0b11100110,    0b1011,0b10010100,0b10010101,    0b1100,0b11101111,0b100111111,0b100111111,0b101111111,0b11011110,0b10010100, 0b1000010, 0b1000011, 0b1000011,0b10010100,0b10010100,0b11011101,0b10010101,0b11010110,0b11010101, 0b1001100,0b10011101,0b10011110,0b10010101,0b10010100,      0b11, 0b1001011,0b10001100, 0b1000011,      0b11,0b11010100,0b111111111,0b110110111,0b11010101,0b10010100,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111110111,0b111111111,0b111111111,0b111111111,0b110110111,0b110111111,0b110110111,0b110110111,0b110110111,0b110111111,0b110111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b110110111,0b110110110,0b110110110,0b110110111,0b111111111,0b110110110,0b111110111,0b110110111,0b110110111,0b111111111,0b110110111,0b110110111,0b101110110,0b110110110,0b110111111,0b110110111,
0b110110111,0b100100110,0b101101110,0b110110111,0b110110111,0b111110111,0b111110111,0b111110111,0b110110110,0b110110110,0b110110111,0b101110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111110,0b111110111,0b111110111, 0b1001011, 0b1010011,0b101110111,0b10011110, 0b1001101, 0b1001100,0b11011101,0b10011101,0b10010101,0b100100111,0b10011110,0b101110111,0b10100110,0b10011101,0b10011101,0b10011101,0b101110111,0b101110111,0b11100111,0b10010110, 0b1010100,0b10011101,0b11100101, 0b1001100,0b10010110, 0b1011101,0b11110111,0b100111111,0b100111111,0b101110111,0b11011101, 0b1000010, 0b1000011, 0b1000011, 0b1000011,0b10001011, 0b1000011, 0b1001100,0b10001101, 0b1001100, 0b1001100,0b10010101, 0b1001100, 0b1001100, 0b1001100, 0b1001100, 0b1000011,0b10010101,      0b11,0b10001011,0b111111111,0b111111111,0b110110111,0b11011100,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b111111111,0b111110111,0b110110111,0b110110110,0b111111111,0b111111111,0b111111111,0b111110111,0b110110111,0b110110110,0b110110111,0b110111111,0b101111111,
0b111111111,0b111111111,0b111111111,0b110111111,0b110110111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110110,0b111111111,0b111111111,0b111111110,0b111111111,0b110110111,0b110110110,0b111111111,0b10001100, 0b1001011,0b101110111,0b11100111, 0b1001101, 0b1000100,0b11010101,0b10011101,0b11100110, 0b1010101,0b11011110,0b10010101,0b10011110, 0b1011101,0b11011101,0b10011101,0b10011101,0b10100110, 0b1011101, 0b1001101,0b100100111, 0b1001100, 0b1010011,0b11100101, 0b1001011,0b100100111,0b10011110,0b100101111,0b101111111,0b100111111,0b11100110, 0b1001100, 0b1001011,0b10001100, 0b1000011, 0b1000011, 0b1000011, 0b1000011, 0b1001100, 0b1001100,0b10001100,0b10001100,0b10001100,0b10001100,0b10001101, 0b1001101,0b10001101, 0b1000100, 0b1001100, 0b1001011,0b110110111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110110,0b110110110,0b111111111,0b110110110,0b111110111,0b110110111,0b111110111,0b111111111,0b111111111,0b111111111,0b111110110,0b111111111,0b111111111,0b110111111,0b101110111,0b110111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b101110110,0b10011100,0b110111111,0b110110111,0b110110110,0b111111110,0b111111110,0b111110110,0b110110110,0b110110111,0b101111111,0b111111111,0b10010100,      0b11,0b100101111,0b11100111,    0b1100,      0b10,0b10010101,0b11011101,0b11100110,0b101110111,0b100110111,0b11101111,0b100110111,0b11100110,0b10011101,0b10010101,    0b1011,0b10100110,0b101110111,0b10011110,0b100100111,0b100100111, 0b1001100,0b11011101,0b10011101,0b10010100,0b100101111,0b100101111,0b11011110,0b101111111,0b101111111,0b10011110,0b10011110,    0b1100, 0b1001100,0b11010101,0b10010100,0b10001100, 0b1001011,      0b11, 0b1001011, 0b1001100, 0b1001100, 0b1001100,0b10001100, 0b1001100,0b10001101,0b10001101, 0b1001100, 0b1001011,0b101110111,0b111111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110110,0b110110110,0b111111111,0b111110110,0b110110110,0b111110110,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b101111111,0b101111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b110111111,0b110111111,0b11010101, 0b1001011,0b11100110,0b11100110, 0b1010100,0b11011101,0b11100101,0b100101110,0b10011100,0b10010101,0b10011101,   0b11100,0b100111111,0b11110111, 0b1011100, 0b1001011, 0b1000011, 0b1010100,0b10100110,0b100101111,0b100110111,0b10100110,0b100101111,0b10011101,0b11011110,0b10001100,0b10011101,0b100110111,0b100101111, 0b1010100,0b11101111, 0b1100100,0b10100110,    0b1100, 0b1001100, 0b1001100, 0b1001011, 0b1001100, 0b1001011, 0b1010100,0b11100110,0b101110111,0b100101111,0b100101111,0b11100110,0b10011101,0b10010101,0b10001100, 0b1001100,0b11010100,0b111111111,0b110111111,0b110111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b110111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111111111,0b110110110,0b110110110,0b110110110,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b101111111,0b110111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b110111111,0b11100101, 0b1000011,0b10011101,0b11100110,0b101110111,0b110110111,0b111111111,0b111111111,0b100101110, 0b1010100,0b11101111,0b11101110,0b11101110,0b11101111, 0b1011100,0b10011101,0b10011100,0b10010101, 0b1010100,0b10100110,0b10100110,0b100111111,0b100111111,0b100110111,0b10010100,0b10010101, 0b1001100,0b10011101,0b100110111,0b100111111,0b100111111,0b100111111,0b100111111,0b10100110,0b100101111,0b10011101,0b11011110,0b11011101,0b11011101,0b10010100,0b10011101,0b10011101,0b100110111,0b100111111,0b101111111,0b101111111,0b101111111,0b101111111,0b110111111,0b110110111,0b110110111,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110111111,0b111111111,0b110110111,0b111111111,0b110110111,0b110110110,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b110110110,0b110110110,0b110110110,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,
0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b101110110,0b110111111,0b110111111,0b100100110, 0b1000011, 0b1010100,0b100100110,0b111110111,0b111111111,0b111111111,0b111111111,0b111110111,      0b10,0b101110111,0b100111111,0b100110111,0b101110111,0b100101111,0b10011100,0b10011101,0b11011101,0b10100101,0b101110111,0b101111111,0b100111111,0b11111111,0b100111111,0b10011101, 0b1001011,0b10001100, 0b1001011,0b10011101,0b100110111,0b100111111,0b100111111,0b100111111,0b100111111,0b101111111,0b101111111,0b11100101,0b11011101,0b11011101,0b11011101,0b11011101,0b11100101,0b11100110,0b100110111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101111111,0b110110111,0b110110111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b110110111,0b110111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,0b111111111,
0b101111111,0b101111111,0b110111111,0b111111111,0b111111111,0b111111111,0b110111111,0b101110111,0b101110110,0b101110111,0b110111111,0b111111111,0b111111111,0b110110111, 0b1000011, 0b1001100,0b100101110,0b110110111,0b111111111,0b11011100,0b101101110,0b100101110,0b10010100, 0b1010100,0b100101111, 0b1011101,0b100101111,0b11100110,0b10011101,0b11011101,0b11011101,0b10011101,0b10100101,0b101110111,0b100110111,0b100111111,0b11111111,0b100111111,0b10011100,0b10001100,0b10010101,    0b1011,0b10100101,0b101111111,0b100111111,0b100111111,0b11101110,0b100101111,0b101111111,0b101110111, 0b1010011,0b11011101,0b11011101,0b11011101,0b100100110,0b101101110,0b11011100,0b100101110,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,0b110111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b110110110,0b110110110,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b101110110,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,
0b100111111,0b100111111,0b101111111,0b110111111,0b110110111,0b100110110,0b11101110,0b11101110,0b11101110,0b11101110,0b100101110,0b110110111,0b111111111, 0b1001010, 0b1001011,0b101101111,0b101110110,0b110110111,      0b10,    0b1011,0b11011101,0b10011101, 0b1010101,    0b1101, 0b1010101,0b11100111, 0b1010101,    0b1100,0b10010101,0b11011101,0b11011101,0b10010101,0b11101110,0b101110111,0b100110111,0b100110111,0b100111111,0b100111111,0b10011100,0b11011110,    0b1011,    0b1011,    0b1011,0b101111111,0b100111111,0b100111111,0b10100101,0b111111111,0b110111111,0b110111111,0b11011101,0b11011101,0b10011101,0b11011101,0b100101110,0b101101110,0b110110111,0b111111111,0b111110111,0b111110111,0b111111111,0b111111111,0b111110111,0b111110111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111110111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110110,0b101110110,0b101110110,0b110110110,0b101110111,0b101110111,0b101111111,0b101111111,0b101111111,0b110111111,0b111111111,
0b111111111,0b110111111,0b101110111,0b101101110,0b101101110,0b100110110,0b101110110,0b110111111,0b110111111,0b101110110,0b100101110,0b100101110, 0b1000100, 0b1000100,0b100100111,0b10100110,0b100101110, 0b1010100,0b10010101,0b10011100,0b10011100,0b10011101, 0b1001101,    0b1101,    0b1100,0b10011101, 0b1001100,0b10010101,0b11011101,0b11011101,0b10011101,0b10011110,0b100110111,0b100111111,0b11111111,0b100111111,0b100111111,0b100101111,0b11011101,0b10001100,0b10001100, 0b1010100,    0b1011,0b10011101,0b101111111,0b100111111,0b101111111,0b101111111,0b100111111,0b101111111,0b10011100,0b100100101,0b101101110,0b111110111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111110111,0b111110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b111110110,0b110110110,0b101110110,0b101101101,0b101100100,0b110101101,0b110110110,0b101110110,0b101110111,0b101110111,0b101110111,0b101111111,0b101111111,0b101111111,
0b110111111,0b111111111,0b110111111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111, 0b1001100, 0b1001011,0b10011101,0b100110111, 0b1011101,0b11100110,0b10011101,0b10011101,0b10011101,0b10011101,0b100100111,    0b1100,0b10011110,0b11100111, 0b1010101,0b10010101,0b10011110,0b10011101,0b10011101,0b10011100,0b100101111,0b100111111,0b100110111,0b100111111,0b100111111,0b101111111,0b10100101, 0b1010100,      0b11,      0b11, 0b1001011,0b11100110,0b101111111,0b100111111,0b100111111,0b100111111,0b101111111,0b101111111,0b101111111,0b100101110,0b101101110,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b101101110,0b101100100,0b110100100,0b110101101,0b110110110,0b110111111,0b110111111,0b110110111,0b111111111,0b111111111,0b110111111,0b110111111,
0b101110110,0b110110111,0b110111111,0b110111111,0b101110111,0b101110111,0b101101110,0b101101110,0b100110101,0b101101110,0b10001100, 0b1000100, 0b1010100,0b101111111, 0b1100101,0b11101111,0b10011100,0b10011101,0b10011101,0b10011101,0b11011110,0b100101111, 0b1011101,0b101111111,   0b10100,0b100110111,0b10011101,0b11011101,0b10011101,0b10011100,0b100101110,0b110111111,0b100110111,0b100110111,0b100110111,0b100111111,0b101111111,    0b1011, 0b1010100,0b11011101,0b10010100,0b11011101,0b101111111,0b101111111,0b100111111,0b100111111,0b101111111,0b101110111,0b101110111,0b110110111,0b110110111,0b110110111,0b111110111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b101110110,0b110101100,0b110100011,0b110100011,0b110101100,0b110110110,0b110111111,0b101110110,0b110110110,0b111110101,0b110101100,0b110101101,0b110111110,
0b111111111,0b110110110,0b101110110,0b101110110,0b101110110,0b110110110,0b110110111,0b110110111,0b101110111,0b10011101, 0b1000011, 0b1001100,0b101110111,0b11101110,0b10100101,0b10011101,0b10011101,0b10011101,0b10011101,0b10011101,    0b1100,      0b11,0b10100101,0b100111111,0b100110111,0b10011101,0b10011101,0b11011100,0b11011101,0b100100110,0b101110111,0b101111111,0b11111111,0b100111111,0b100111111,0b100110111,0b100110111,0b10011101,0b11011101,0b11011101,0b101101111,0b110111111,0b101111111,0b101111111,0b101111111,0b101111111,0b101110111,0b101110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110111111,0b110111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b111110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110101101,0b110100011,0b111100011,0b110100100,0b110101101,0b110110110,0b101101101,0b100100100,0b111110101,0b111100100,0b110100100,0b101101100,0b110111110,
0b111111111,0b110111110,0b110110110,0b110110111,0b111110111,0b111110111,0b110110110,0b110110111,0b11011101, 0b1001011, 0b1001100,0b101110111,0b101110111, 0b1010100,0b10011101,0b10011101,0b10011101,0b11011101,0b10011100,0b11100110,0b11101111,0b10100110,0b100111111,0b100110111,0b11101110, 0b1011100,0b11011101,0b11011101,0b11011101,0b100101110,0b101110111,0b100111111,0b100110111,0b11110111,0b100111111,0b100110111,0b11101110,0b10011100,0b101101110,0b110111111,0b110111111,0b101101110,0b110111111,0b110111111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111110111,0b110110111,0b110110111,0b110110111,0b110111111,0b110110111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110101101,0b111100011,0b111100011,0b110100100,0b110101101,0b110101101,0b101100011,0b111111110,0b111111110,0b111101101,0b110100100,0b110110110,0b110111111,
0b110110110,0b110110110,0b110110110,0b110110110,0b111110111,0b110110110,0b110110110,0b100011101,0b10001011,0b11011101,0b101110111,0b101110111,0b11100110, 0b1001100,0b10011101,0b10011101,0b11011101,0b10011101,0b10011101,0b100110111,0b100110111,0b100110111,0b100110111,0b100110111,0b10011100,0b11011101,0b101101110,0b100100101,0b11100101,0b100101110,0b100110111,0b100110111,0b100111111,0b100110111,0b100110111,0b101111111,0b100101101,0b110110111,0b110110111,0b110110111,0b110110111,0b110111111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110110,0b110110111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110101101,0b110100011,0b101011011,0b100011011,0b101100011,0b110100100,0b111101101,0b111111111,0b111111110,0b101101100,0b111110110,0b111111111,0b111111111,
0b110110110,0b110110110,0b110110110,0b110110111,0b110110110,0b110110111,0b100100101,0b101100110,0b111110111,0b101110111,0b101110111,0b100110111, 0b1010100,0b10010101,0b10011101,0b10011101,0b10011101,0b10011101,0b100110111,0b100110111,0b100110111,0b100110111,0b101110111,0b100101110,0b100100101,0b110110111,0b101101111,0b11100101,0b10011101,0b100110111,0b100110111,0b100110111,0b101110111,0b101110111,0b110110111,0b110111111,0b111111111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b111111111,0b111111111,0b111111111,0b110111111,0b110111111,0b111111111,0b110111111,0b101110110,0b110101101,0b101110110,0b110110111,0b101101101,0b101011011,0b101011011,0b100011011,0b101011011,0b110100100,0b111110110,0b110110110,0b101101101,0b111111111,0b111111111,0b111111111,0b111111111,
0b110110110,0b110110110,0b110110111,0b110110110,0b110110110,0b101101110,0b111111111,0b111111111,0b100101110,0b100110110,0b100111111,0b11101110, 0b1010100,0b10011101,0b10011101,0b10011101,0b10010100,0b11100110,0b100101111,0b10100101,0b10100101,0b101110110,0b110111111,0b110110111,0b110110111,0b110110111,0b110110111,0b100101110,0b100101110,0b101111111,0b101110111,0b110111111,0b110110111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111110111,0b110110111,0b110110111,0b110110111,0b111110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110111111,0b110110110,0b110110110,0b111111111,0b111111111,0b111111111,0b110110111,0b110110110,0b110110110,0b110111111,0b110111111,0b100101101,0b101100100,0b101100100,0b101100100,0b101100100,0b100011011,0b101011011,0b101100100,0b101011011,0b100011011,0b101100100,0b101101101,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,
0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b111111111,0b111111111,0b100101110,0b11101110,0b100111111,0b100110111,0b10011101,0b10010101,0b10010100,0b10010100,0b10010100,0b11100101,0b101110111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110110110,0b110111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111110110,0b110110110,0b111110110,0b111111111,0b111111111,0b110110110,0b111111111,0b111111111,0b111111111,0b101110110,0b101101110,0b101101110,0b101110110,0b110111111,0b110111111,0b100101101,0b110100100,0b101011011,0b101100011,0b101011011,0b100011011,0b101011100,0b101011100,0b100011011,0b100011010,0b101100011,0b110101101,0b110110110,0b110110111,0b111111111,0b111111111,0b111111111,
0b110110110,0b110110110,0b110110111,0b110110111,0b111111111,0b111111111,0b110110110,0b100101110,0b100110111,0b100110111,0b11100101,0b11100101,0b100100110,0b101101110,0b101101111,0b110110111,0b110110111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110111,0b110110110,0b110110110,0b111110111,0b111111111,0b111111111,0b111110111,0b110110111,0b111111111,0b111111111,0b101110110,0b101101110,0b101110111,0b101110110,0b101101110,0b110110111,0b110110111,0b100100101,0b101011011,0b101011011,0b110011011,0b101011010,0b100010010,0b100010010,0b100010010,0b100010010,0b101011010,0b110011010,0b110100011,0b110100100,0b101101101,0b101101110,0b110111111,0b111111111,
0b110110111,0b110110111,0b110110111,0b110110111,0b111110111,0b111110111,0b110110111,0b110110111,0b101110111,0b110110111,0b110110111,0b110110111,0b111110111,0b110110111,0b110111111,0b110111111,0b110110111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110111,0b110110110,0b110110111,0b110110111,0b111110111,0b111110111,0b110111111,0b101101110,0b100101110,0b100101110,0b100101110,0b100101110,0b101110110,0b110110111,0b101101110,0b101100101,0b101011100,0b101011011,0b101011011,0b101011011,0b101010010,0b100010010,0b100010010,0b100011011,0b100010010,0b101011010,0b110011010,0b110011011,0b101100011,0b100100100,0b101110110,0b110111111,
0b111110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b110110111,0b111110111,0b110110111,0b111110111,0b111111111,0b111111111,0b110110111,0b110110111,0b110111111,0b111111111,0b110111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b101101110,0b101110111,0b100101110,0b100101101,0b101110110,0b110110111,0b110110110,0b110110110,0b110101110,0b101101110,0b101101101,0b101100100,0b100011011,0b100010010,0b101010010,0b100011011,0b101100100,0b101100100,0b101011011,0b110011011,0b110011011,0b101100011,0b101101101,0b110110110,0b111111111,
0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111110111,0b110110111,0b111110111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110111110,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b110111111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110111,0b110110111,0b110110111,0b110110110,0b110110111,0b110110111,0b110110111,0b101110110,0b100101101,0b101101110,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110111,0b110110110,0b101100100,0b101011010,0b101010010,0b101011010,0b100100100,0b100101101,0b100101101,0b100100101,0b101100100,0b101100100,0b101101101,0b110111111,0b111111111,0b111111111,
0b110110111,0b110110110,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b111111111,0b111111111,0b110110110,0b111110111,0b111110111,0b111110111,0b110110110,0b111110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110101110,0b101100100,0b101011010,0b110011010,0b101011011,0b100100100,0b100101101,0b100101110,0b101110111,0b100101110,0b100101110,0b101110111,0b110110111,0b110110110,0b111110110,
0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110111111,0b110110111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110110,0b110110110,0b110110110,0b110110111,0b110110110,0b110110110,0b110110110,0b111111110,0b111111111,0b111111111,0b110110110,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110101110,0b101100100,0b101011010,0b110011010,0b101011011,0b100100100,0b101101110,0b101101111,0b100100110,0b10011101,0b11100110,0b101110111,0b110110110,0b110110110,0b111110110,
0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b111111111,0b110110111,0b110110111,0b110110111,0b110110111,0b110110111,0b111111111,0b111111111,0b111111111,0b111111111,0b111110111,0b110110110,0b110110111,0b110110111,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110110,0b110110111,0b110110111,0b110110110,0b110110111,0b111111111,0b110110110,0b101100100,0b101011011,0b110011011,0b110011011,0b110101101,0b110110110,0b100100110,0b11010101,0b10010100,0b11011110,0b101101111,0b110110110,0b110110110,0b110110110"""
a=a.split('\n')
for i in a:
    print('(',end='')
    for g in i.split(','):
        if g=='':
            continue
        g=list(g)
        while(len(g)<11):
            g.insert(2,'0')
            if len(g)==11:
                break;
        g[0:2]=' "'
        g.append('"')
        for gg in g:
            print(gg,end='')
        print(',',end='')
    print('),')
# Out:
# ( "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010001111", "010001111", "010001111", "010010111", "010010111", "010001111", "010001111", "011010111", "011010111", "010001111", "011001111", "011010111", "010010111", "010010111", "010001111", "010010111", "011010111", "010001111", "011010111", "011010111", "011010111", "011010111", "010001111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "011010111", "011001111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010010111", "010001111", "010001111", "010001111", "010001111", "010001111", "010001111", "010010111", "010010111", "010010111", "010010111", "010010111", "010001111", "010001111", "010010111", "011010111", "011010111", "010001111", "010001111", "010001111", "010010111", "010010111", "0100101
# ...

# %%
a='0b10110111'
a=list(a)
a.insert(2,0)
a
# Out:
# ['0', 'b', 0, '1', '0', '1', '1', '0', '1', '1', '1']
