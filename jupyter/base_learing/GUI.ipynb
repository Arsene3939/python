# %% [markdown]
# 參考網站https://www.itread01.com/content/1547705544.html
# tkinter 為 Python 內建的 GUI 程式庫 (library) ，基本使用順序如下
#
# 建立 Tk 物件， Tk 物件是視窗應用程式。
# 建立 Frame 物件， Frame 是基本的視窗。
# 建立所需的視窗元件物件，再利用 pack() 或 grid() 方法設定視窗元件如何在視窗上顯示。
# Tk 物件呼叫 mainloop() 方法，維持視窗在螢幕上顯示。
# tkinter 有以下的視窗元件
#
# 類別	說明
# Button	按鈕。
# Canvas	長方形區域。
# Checkbutton	核取按鈕。
# Entry	文字輸入欄。
# Frame	視窗。
# Label	文字標籤。
# LabelFrame	文字標籤視窗。
# Listbox	列表選單。
# Menu	選單列的下拉式選單。
# MenuButton	選單的選項。
# Message	類似 Label ，可多行。
# OptionMenu	下拉式的選項選單。
# PaneWindow	類似 Frame ，可包含其他視窗元件。
# Radiobutton	單選按鈕。
# Scale	拉桿。
# Scrollbar	捲軸。
# Spinbox	微調器
# Text	文字方塊。
# Toplevel	新增視窗。
# 每一種視窗元件都有為數不等的屬性可詳細設定，實際的程式範例比較容易理解使用方式，例如以下程式為基本使用

# %%
import turtle
# 引入套件
import tkinter as tk

# 建立主視窗和 Frame（把元件變成群組的容器）
window = tk.Tk()
top_frame = tk.Frame(window)
window.geometry('800x600')##幾何
window.configure(background='white')
# 將元件分為 top/bottom 兩群並加入主視窗





# 建立事件處理函式（event handler），透過元件 command 參數存取
def echo_hello():
    print('hello world :)')
    
    

    
def conculate():
    var=instr.get()
    text.insert('end',var)
    label.set(var)
    
    
left_button = tk.Button(window, text='Red', fg='red',command=conculate)
left_button.grid(row=5,column=5,ipadx=10,ipady=10,padx=10,pady=10)







label = tk.StringVar()    # 將label標籤的內容設定為字元型別，用var來接收hit_me函式的傳出內容用以顯示在標籤上
l = tk.Label(window, text="0 , 0", bg='green', fg='white', font=('Arial', 12))
# 說明： bg為背景，fg為字型顏色，font為字型，width為長，height為高，這裡的長和高是字元的長和高，比如height=2,就是標籤有2個字元這麼高
l.place(x=0,y=0,anchor='nw')
l = tk.Label(window, text="200 , 200", bg='green', fg='white', font=('Arial', 12))
# 說明： bg為背景，fg為字型顏色，font為字型，width為長，height為高，這裡的長和高是字元的長和高，比如height=2,就是標籤有2個字元這麼高
l.place(x=200,y=200,anchor='nw')
l = tk.Label(window, text="400 , 400", bg='green', fg='white', font=('Arial', 12))
# 說明： bg為背景，fg為字型顏色，font為字型，width為長，height為高，這裡的長和高是字元的長和高，比如height=2,就是標籤有2個字元這麼高
l.place(x=400,y=400,anchor='nw')
l = tk.Label(window, text="0 , 200", bg='green', fg='white', font=('Arial', 12))
# 說明： bg為背景，fg為字型顏色，font為字型，width為長，height為高，這裡的長和高是字元的長和高，比如height=2,就是標籤有2個字元這麼高
l.place(x=0,y=200,anchor='nw')




l = tk.Label(window, text="grid 1,1", bg='green', fg='white', font=('Arial', 12))
# 說明： bg為背景，fg為字型顏色，font為字型，width為長，height為高，這裡的長和高是字元的長和高，比如height=2,就是標籤有2個字元這麼高
l.grid(row=1,column=1,ipadx=10,ipady=10,padx=10,pady=10)


text=tk.Text(window,width=10,height=1, font=('Arial', 20))
text.grid(row=1,column=2,ipadx=10,ipady=10,padx=10,pady=10)






instr = tk.Entry(window)
instr.grid(row=3,column=2,ipadx=10,ipady=10,padx=10,pady=10)



# 運行主程式
window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-1-a556209317c1>", line 27, in conculate
#     left_button.set(bg='red')
# AttributeError: 'Button' object has no attribute 'set'

# %%
#####################           extra window              #########################
import tkinter as tk #python3
import time
#root application, can only have one of these.
root = tk.Tk() 
root.geometry("500x500")
#put a label in the root to identify the window.
label1 = tk.Label(root, text="""this is root
closing this window will shut down app""")
label1.pack()

#you can make as many Toplevels as you like
extra_window = tk.Toplevel(root)
extra_window.geometry("500x100")
label2 = tk.Label(extra_window, text="""this is extra_window
closing this will not affect root""")
label2.pack(side=tk.LEFT)
#extra_window.destroy()
root.mainloop()

# %%
################             experiment            ##############################
import turtle
# 引入套件
import tkinter as tk
a=0
# 建立主視窗和 Frame（把元件變成群組的容器）
window = tk.Tk()
window.geometry('800x600')##幾何
window.configure(background='white')

conculate=lambda x:(
    global a
    a=not a
    text.insert('insert',str((int(a))
    )

    
    
    
# 以下為 top 群組
left_button = tk.Button(window, text='Red', fg='red',command=conculate)
# 讓系統自動擺放元件，預設為由上而下（靠左）
left_button.pack(side=tk.LEFT)


text=tk.Text(window,width=20,height=1, font=('Arial', 10))
text.pack(side=tk.RIGHT)


# 運行主程式
window.mainloop()
# Out:
#   File "<ipython-input-1-3870ab7e2a21>", line 12
#     global a
#          ^
# SyntaxError: invalid syntax
