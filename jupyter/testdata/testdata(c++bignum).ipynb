# %%
from random import *
s="5123456789+-*/"
ls=[]
for i in range(20):
    seq=""
    flag=1
    t=randint(0,14)
    n=0
    for i in range(randint(20,35)):
        if t>9:
            flag=1
        else:
            n+=1
        if flag:
            t=randint(0,9)
            flag=0
            n+=1
        elif n>=3:
            t=randint(10,13)
            n=0
        else:
            t=randint(0,13)
            
        seq+=s[t]
    if seq[-1] in "+-*/":
        seq=seq[:-1]
    ls.append(seq)
for i in ls:
    print(i)
print()
for i in ls:
    eval(i)
    print(i)
    print("%.10f"%eval(i))
# Out:
# 1-5/8*5+4+56*14*73+75+22*1
# 5/5+2-55-2+2*46/17/8/4*51/87/55-9
# 9+1+3+69*7/5-8-5/4+2/55+68-63
# 9-3*4/4-4+19/4*6+82+69*4/6-32*82/5
# 8+8-9/71*51+3/6-53*8/5/59-57*51+7
# 2/6+6*45-3-1/81-6+8-8*1*11
# 6-65/18*7+9/93-89/3/3*2*5
# 6*5-4*55-77/73-74+5-9/17/85
# 1+5*97/48/59/6-5*53-85/4
# 3-3/7*78/5/4-52*85*56+65+5*5+54/8
# 7*2/5/5*6+8+5/52/6+5+1-1*8+2+34
# 2-9/77+34-3/7-35*5+4
# 3/3/7/8/8+75*82*11+36/75-49-5/7*6-1
# 2+57-52/59/11*8+2*69/21-35*2/3-5
# 9-37-6+1-61/5-7*64-45*2/6+98*83-37
# 8/3+19+54*4*1+34-72/75/52/4
# 52-52/97-39/44*75-5/3
# 2-6-6+91-75/98-5+1*4*5/97+39/12/9
# 1-28-94+15+6*3+9+6+4*5/58
# 1/63/49/45-3*3*45+11+8-5+66/5
#
# 1-5/8*5+4+56*14*73+75+22*1
# 57330.8750000000
# 5/5+2-55-2+2*46/17/8/4*51/87/55-9
# -62.9981974922
# 9+1+3+69*7/5-8-5/4+2/55+68-63
# 105.3863636364
# 9-3*4/4-4+19/4*6+82+69*4/6-32*82/5
# -366.3000000000
# 8+8-9/71*51+3/6-53*8/5/59-57*51+7
# -2891.4020768680
# 2/6+6*45-3-1/81-6+8-8*1*11
# 181.3209876543
# 6-65/18*7+9/93-89/3/3*2*5
# -118.0698924731
# ...

# %%
import random
ls=[]
for x in range(20):
    num=[]
    for i in range(2):
        r=random.randint(-100000,100000)/1000
        if r<0:
            num.append("(%s)"%str(r))
        else:
            num.append(str(r))
    opr=list("/")
    for i in range(len(num)-1):
        num[0]+=opr[0]+num[1]
        if(random.randint(0,3)==1):
            num[0]="(%s)"%num[0]
        num.pop(1)
        random.shuffle(opr)
        random.shuffle(num)
    ls.append(num[0])
for i in ls:
    print(i)
print()
for i in ls:
    print(i)
    try:
        print("%.10f"%eval(i))
    except Exception as e:
        print("error ",end="")
        print(e)
# Out:
# 17.649/85.21
# 62.774/(-46.248)
# ((-1.698)/25.709)
# 60.248/59.91
# (42.509/(-22.134))
# 64.556/(-25.974)
# (-54.617)/94.455
# 79.303/(-15.486)
# 16.239/76.878
# (-66.966)/(-89.386)
# 25.93/(-8.782)
# (-79.184)/82.488
# (90.801/67.954)
# ((-62.445)/(-11.651))
# (-51.468)/21.462
# ((-85.468)/59.801)
# (-19.745)/(-30.679)
# ((-82.949)/15.98)
# 21.535/(-5.456)
# ((-69.393)/(-20.844))
#
# 17.649/85.21
# 0.2071235770
# 62.774/(-46.248)
# -1.3573343712
# ((-1.698)/25.709)
# -0.0660469096
# 60.248/59.91
# 1.0056417960
# (42.509/(-22.134))
# -1.9205295021
# 64.556/(-25.974)
# -2.4854084854
# (-54.617)/94.455
# -0.5782330210
# 79.303/(-15.486)
# -5.1209479530
# 16.239/76.878
# 0.2112307812
# (-66.966)/(-89.386)
# 0.7491777236
# 25.93/(-8.782)
# -2.9526303803
# (-79.184)/82.488
# -0.9599456891
# (90.801/67.954)
# 1.3362127321
# ((-62.445)/(-11.651))
# 5.3596257832
# (-51.468)/21.462
# -2.3980989656
# ((-85.468)/59.801)
# -1.4292068695
# (-19.745)/(-30.679)
# 0.6435998566
# ((-82.949)/15.98)
# ...
