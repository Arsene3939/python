# %% [markdown]
# # 5.4 梯度下降法

# %% [markdown]
# 梯度下降法(gradient descent)是最佳化理論裡面的一個一階找最佳解的一種方法，主要是希望用梯度下降法找到函數(剛剛舉例的式子)的局部最小值，因為梯度的方向是走向局部最大的方向，所以在梯度下降法中是往梯度的反方向走。

# %%
這邊我們先大概說一下梯度， 要算一個函數f(x)的梯度有一個前提，就是這個函數要是任意可微分函數，這也是深度學習為什麼都要找可微分函數出來當激活函數(activation function)。
一維度的純量x的梯度，通常用f’(x)表示。
多維度的向量x的梯度，通常用∇f(x)表示。

白話一點，一維度的純量x的梯度就是算f(x)對x的微分，

多維度的向量x的梯度就是算f(x)對x所有元素的偏微分
一維度的容易理解，上面也有範例。

多維度的梯度，一般公式寫的是

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-5.05, 5, 0.1)
y = np.arange(-5.05, 5, 0.1)
xx, yy = np.meshgrid(x, y, sparse=True)
z = xx**2 + yy**2
#h = plt.contourf(x,y,z)
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection="3d")
#ax.plot_surface(xx, yy, z, rstride=1, cstride=1,       cmap='winter', edgecolor='none')
ax.plot_wireframe(xx, yy, z, color='black')
ax.set_title('surface');
ax.view_init(60, 35)
X=[1]
Y=[1]

Sn = np.array([-5,5])
ita = 0.1
x = Sn[0]
y = Sn[1]
z = x**2 + y**2
ax.scatter3D(x, y, z,s=100, c='red');
for i in range(10):
    x = Sn[0]
    y = Sn[1]
    gxy = np.array([2*x , 2*y])
    Sn1 = Sn - ita * gxy
    Sn = Sn1
    x = Sn[0]
    y = Sn[1]
    z = x**2 + y**2
    ax.scatter3D(x, y, z,s=50, c='red');

# %%
# Making the imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# Preprocessing Input data
X = 2 * np.random.random(100)
Y = 2 -5 * X+np.random.normal(0,0.2, 100)
plt.scatter(X, Y)
plt.show()

# %%
# Building the model
m = 0
c = 0

L = 0.01  # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    
print (m, c)

# Making predictions
Y_pred = m*X + c

plt.scatter(X, Y) 
#plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
plt.plot(X, Y_pred, color='red')
plt.show()
# Out:
# -4.753127010661985 1.7140061283924848

# %%
X = 2 * np.random.random(10)
Y = 4 + 3 * X+np.random.normal(0, 1, 10)
print(X)
print(Y)
# Out:
# [1.00664115 0.08538322 1.78996356 0.23932357 0.91974621 1.98087588
#  1.70111956 1.18089719 1.14953141 0.26953697]
# [ 7.84554444  5.21474078  8.69040035  4.33720426  7.39294482 10.13241544
#  10.3732034   7.99114031  8.5598519   7.02797462]
